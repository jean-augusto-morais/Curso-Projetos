# %% [markdown]
# # Sendo a base apresentada no arquivo abaixo:
# - https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce?select=olist_customers_dataset.csv
#     - Já disponível no banco de dados `vendas_db.db` através do link:
#         - https://drive.google.com/file/d/1eONzrbEu5BoijDRj56gjL_2Ik5qxtR6U/view?usp=sharing
# <br><br>
# - Sua tarefa é ajudar a área de negócios a **montar uma apresentação para a diretoria** para provar a **necessidade de investistimento em uma área de melhoria da experência do cliente ao ter um atraso na entrega**
# <br><br>
# - Algumas considerações são importantes
#     - O **time de logística não considera que o atraso na entrega é um problema relevante** e falou que, em média, as entregas estão sendo feitas 10 dias antes do prazo combinado
#     - Não é desejado a previsão de uma entrega atrasada, apenas a **exposição que esse é um problema que pode impactar os clientes**
#     - Não queremos uma abordagem de: "nenhuma entrega pode atrasar". Vamos ser mais tranquilos e seguir na linha de: **"uma entrega pode atrasar. Como eu posso melhorar a experiência do cliente caso isso aconteça?"**

# %% [markdown]
# ### Preparando nosso "ambiente"

# %%
# Importando o sqlite3
import sqlite3

# %%
# Importando o pandas
import pandas as pd

# %%
# Criando uma conexão
con = sqlite3.connect('vendas_db.db')

# %%
# E então criando o cursor
cur = con.cursor()

# %%
# Usando a função python que já havíamos criado
def executa_consulta(consulta):
    resultado = cur.execute(consulta).fetchall()
    resultado = pd.DataFrame(resultado)
    colunas = [i[0] for i in cur.description]
    if resultado.shape[1] > 0:
        resultado.columns = colunas
    print(resultado.shape)
    display(resultado.head(3))
    return resultado

# %% [markdown]
# ### <font color='blue'> 2. Existe relação da avaliação do cliente com o atraso do pedido? </font>

# %%
# Vamos começar visualizando a tabela de avaliações
avaliacoes = executa_consulta('SELECT * FROM order_reviews')
# Out:
# (99224, 8)
#    index                         review_id                          order_id  \
# 0      0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                 None                   None
# 1             5                 None                   None
# 2             5                 None                   None
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24

# %%
# Verificando a quantidade de avaliações em cada uma das notas
avaliacoes.review_score.value_counts().sort_index()
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %%
# Visualizando em percentual
round((avaliacoes.review_score.value_counts().sort_index()/avaliacoes.shape[0])*100,1)
# Out:
# review_score
# 1    11.5
# 2     3.2
# 3     8.2
# 4    19.3
# 5    57.8
# Name: count, dtype: float64

# %%
# Podemos também visualizar a tabela de pedidos
pedidos = executa_consulta('SELECT * FROM orders')
# Out:
# (99441, 9)
#    index                          order_id                       customer_id  \
# 0      0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00

# %%
# Relacionando as duas tabelas
avaliacoe_pedidos = executa_consulta('SELECT * FROM orders o \
                                     LEFT JOIN order_reviews ore \
                                     ON o.order_id = ore.order_id')
# Out:
# (99992, 17)
#    index                          order_id                       customer_id  \
# 0      0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date    index                         review_id  \
# 0           2017-10-18 00:00:00  32790.0  a54f0611adc9ed256b57ede6b6eb5114
# 1           2018-08-13 00:00:00  29158.0  8d5266042046a06655c8db133d120ba5
# 2           2018-09-04 00:00:00   4323.0  e73b67b67587f7644d5bd1a52deb1b01
#
#                            order_id  review_score review_comment_title  \
# 0  e481f51cbdc54678b7cc49136f2d6af7           4.0                 None
# 1  53cdb2fc8bc7dce0b6741e2150273451           4.0     Muito boa a loja
# 2  47770eb9100c2d0c44946d9cf07ec65d           5.0                 None
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1                               Muito bom o produto.  2018-08-08 00:00:00
# 2                                               None  2018-08-18 00:00:00
#
#   review_answer_timestamp
# 0     2017-10-12 03:43:48
# 1     2018-08-08 18:37:50
# 2     2018-08-22 19:07:58

# %%
# Podemos pegar apenas as colunas que quisermos utilizar
avaliacao_ordem = executa_consulta('SELECT \
                                      o.order_id \
                                     ,o.order_purchase_timestamp \
                                     ,o.order_delivered_customer_date \
                                     ,o.order_estimated_delivery_date \
                                     ,ore.review_score \
                                     FROM orders o \
                                     LEFT JOIN order_reviews ore \
                                     ON o.order_id = ore.order_id')
# Out:
# (99992, 5)
#                            order_id order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33
# 1  53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37
# 2  47770eb9100c2d0c44946d9cf07ec65d      2018-08-08 08:38:49
#
#   order_delivered_customer_date order_estimated_delivery_date  review_score
# 0           2017-10-10 21:25:13           2017-10-18 00:00:00           4.0
# 1           2018-08-07 15:27:45           2018-08-13 00:00:00           4.0
# 2           2018-08-17 18:06:29           2018-09-04 00:00:00           5.0

# %%
# Todos os pedidos possuem avaliação?
avaliacao_ordem[avaliacao_ordem.review_score.isnull()]
# Out:
#                                order_id order_purchase_timestamp  \
# 16     403b97836b0c04a622354cf531062e5f      2018-01-02 19:00:43
# 154    6942b8da583c2f9957e990d028607019      2018-01-10 11:33:07
# 311    4906eeadde5f70b308c20c4a8f20be02      2017-12-08 04:45:26
# 382    b7a4a9ecb1cd3ef6a3e36a48e200e3be      2017-05-19 18:13:54
# 390    59b32faedc12322c672e95ec3716d614      2018-06-27 11:10:11
# ...                                 ...                      ...
# 99242  0c384d67524b5b92aa2fa6c8baa9a983      2017-06-05 19:20:11
# 99327  906a6b0a96d89ee226e4977e99b80b9e      2017-08-28 15:14:21
# 99554  5333db16fe357175d39c82840dd3269d      2018-03-10 18:18:20
# 99684  2f2df159f26ddb73d55ee72372200d3e      2017-07-17 01:19:50
# 99796  dff2b9b8d7cfc595836945e1443789c3      2018-07-16 12:59:02
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 16              2018-01-20 01:38:59           2018-02-06 00:00:00
# 154                            None           2018-02-07 00:00:00
# 311             2018-01-09 18:04:58           2018-01-03 00:00:00
# 382             2017-06-08 07:53:42           2017-06-16 00:00:00
# 390             2018-07-06 16:37:36           2018-07-26 00:00:00
# ...                             ...                           ...
# 99242           2017-06-13 14:09:21           2017-06-27 00:00:00
# 99327           2017-09-05 19:47:44           2017-09-18 00:00:00
# 99554           2018-04-03 15:32:52           2018-03-29 00:00:00
# 99684           2017-07-26 09:44:00           2017-08-09 00:00:00
# 99796           2018-07-20 20:41:32           2018-08-07 00:00:00
#
#        review_score
# 16              NaN
# 154             NaN
# 311             NaN
# 382             NaN
# 390             NaN
# ...             ...
# 99242           NaN
# 99327           NaN
# 99554           NaN
# 99684           NaN
# 99796           NaN
#
# [768 rows x 5 columns]

# %%
# Verificando a diferença entre as duas tabelas
pedidos.shape[0] - avaliacoes.shape[0]
# Out:
# 217

# %% [markdown]
# **Eu tenho 768 pedidos sem avaliação mas apenas 217 linhas a mais**<br>
# **Será que algum pedido possui mais de 1 avaliação?**<br>

# %%
# Visualizando se alguma ordem apareceu mais de 1 vez
avaliacao_ordem.order_id.value_counts()
# Out:
# order_id
# 8e17072ec97ce29f0e1f111e598b0c85    3
# 03c939fd7fd3b38f8485a0f95798f1f6    3
# c88b1d1b157a9999ce368f218a407141    3
# df56136b8031ecd28e200bb18e6ddb2e    3
# 95442deb81a5d91c97c0df96b431634a    2
#                                    ..
# 94a1020970476388adf12c46628499be    1
# b266c12d9bececa3942c1bef84f13716    1
# e82e0697786dcef38c215ec9d2dc308a    1
# e940e33cefca8e48b759474760c2fb41    1
# 66dea50a8b16d9b4dee7af250b4be1a5    1
# Name: count, Length: 99441, dtype: int64

# %%
# Verificando essa primeira ordem na tabela de pedidos
pedidos[pedidos.order_id == 'c88b1d1b157a9999ce368f218a407141']
# Out:
#        index                          order_id  \
# 37179  37179  c88b1d1b157a9999ce368f218a407141
#
#                             customer_id order_status order_purchase_timestamp  \
# 37179  ae0fb7b01c548c4fd30f19f55453ec4a    delivered      2017-07-17 22:44:23
#
#          order_approved_at order_delivered_carrier_date  \
# 37179  2017-07-18 22:50:12          2017-07-20 15:27:41
#
#       order_delivered_customer_date order_estimated_delivery_date
# 37179           2017-07-21 17:06:30           2017-08-01 00:00:00

# %%
# Agora verificando na tabela de avaliações
avaliacoes[avaliacoes.order_id =='c88b1d1b157a9999ce368f218a407141']
# Out:
#        index                         review_id  \
# 1985    1985  ffb8cff872a625632ac983eb1f88843c
# 82525  82525  202b5f44d09cd3cfc0d6bd12f01b044c
# 89360  89360  fb96ea2ef8cce1c888f4d45c8e22b793
#
#                                order_id  review_score review_comment_title  \
# 1985   c88b1d1b157a9999ce368f218a407141             3                 None
# 82525  c88b1d1b157a9999ce368f218a407141             5                 None
# 89360  c88b1d1b157a9999ce368f218a407141             5                 None
#
#       review_comment_message review_creation_date review_answer_timestamp
# 1985                    None  2017-07-22 00:00:00     2017-07-26 13:41:07
# 82525                   None  2017-07-22 00:00:00     2017-07-26 13:40:22
# 89360                   None  2017-07-21 00:00:00     2017-07-26 13:45:15

# %% [markdown]
# **Agora precisamos tomar uma decisão de negócio!**<br>
# **O que fazer com registros com mais de 1 linha?**

# %%
# E se usarmos a média?
media = avaliacao_ordem.groupby('order_id')['review_score'].mean().reset_index()
media.columns = ['order_id','media_nota']

# %%
# Verificando as notas
media.media_nota.value_counts().sort_index()
# Out:
# media_nota
# 1.000000    11316
# 1.500000        8
# 2.000000     3125
# 2.500000       34
# 3.000000     8136
# 3.333333        1
# 3.500000       25
# 4.000000    19018
# 4.333333        1
# 4.500000       54
# 5.000000    56955
# Name: count, dtype: int64

# %% [markdown]
# **O que podemos fazer com essas médias com valores não inteiros?**

# %%
# E se usarmos o máximo?
maximo = avaliacao_ordem.groupby('order_id')['review_score'].max().reset_index()
maximo.columns = ['order_id','maximo_nota']

# %%
# Verificando as notas
maximo.maximo_nota.value_counts().sort_index()
# Out:
# maximo_nota
# 1.0    11316
# 2.0     3121
# 3.0     8116
# 4.0    19044
# 5.0    57076
# Name: count, dtype: int64

# %% [markdown]
# **Podemos trazer do SQL tanto a média quanto o máximo e então aprofundar na análise**

# %%
# Primeiramente fazendo o join entre as tabelas
avaliacao_ordem = executa_consulta('SELECT \
                                      o.order_id \
                                     ,o.order_purchase_timestamp \
                                     ,o.order_delivered_customer_date \
                                     ,o.order_estimated_delivery_date \
                                     ,ROUND(AVG(ore.review_score),1) as media_nota \
                                     ,ROUND(MAX(ore.review_score),1) as maximo_nota \
                                     FROM orders o \
                                     LEFT JOIN order_reviews ore \
                                     ON o.order_id = ore.order_id \
                                     WHERE ore.review_score IS NOT NULL \
                                     GROUP BY \
                                      o.order_id \
                                     ,o.order_purchase_timestamp \
                                     ,o.order_delivered_customer_date \
                                     ,o.order_estimated_delivery_date')
# Out:
# (98673, 6)
#                            order_id order_purchase_timestamp  \
# 0  00010242fe8c5a6d1ba2dd792cb16214      2017-09-13 08:59:02
# 1  00018f77f2f0320c557190d7a144bdd3      2017-04-26 10:53:06
# 2  000229ec398224ef6ca0657da4fc703e      2018-01-14 14:33:31
#
#   order_delivered_customer_date order_estimated_delivery_date  media_nota  \
# 0           2017-09-20 23:43:48           2017-09-29 00:00:00         5.0
# 1           2017-05-12 16:04:24           2017-05-15 00:00:00         4.0
# 2           2018-01-22 13:19:16           2018-02-05 00:00:00         5.0
#
#    maximo_nota
# 0          5.0
# 1          4.0
# 2          5.0

# %%
# Verificando as informações da base
avaliacao_ordem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98673 entries, 0 to 98672
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       98673 non-null  object
#  1   order_purchase_timestamp       98673 non-null  object
#  2   order_delivered_customer_date  95830 non-null  object
#  3   order_estimated_delivery_date  98673 non-null  object
#  4   media_nota                     98673 non-null  float64
#  5   maximo_nota                    98673 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 4.5+ MB

# %%
# Transformando as colunas de data em datas
colunas_datas = ['order_purchase_timestamp','order_delivered_customer_date','order_estimated_delivery_date']

for i in colunas_datas:
    avaliacao_ordem[i] = pd.to_datetime(avaliacao_ordem[i], format = 'mixed')

# %%
# Verificando novamente as informações da base
avaliacao_ordem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98673 entries, 0 to 98672
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       98673 non-null  object
#  1   order_purchase_timestamp       98673 non-null  datetime64[ns]
#  2   order_delivered_customer_date  95830 non-null  datetime64[ns]
#  3   order_estimated_delivery_date  98673 non-null  datetime64[ns]
#  4   media_nota                     98673 non-null  float64
#  5   maximo_nota                    98673 non-null  float64
# dtypes: datetime64[ns](3), float64(2), object(1)
# memory usage: 4.5+ MB

# %%
# Verificando as primeiras linhas da tabela
avaliacao_ordem.head()
# Out:
#                            order_id order_purchase_timestamp  \
# 0  00010242fe8c5a6d1ba2dd792cb16214      2017-09-13 08:59:02
# 1  00018f77f2f0320c557190d7a144bdd3      2017-04-26 10:53:06
# 2  000229ec398224ef6ca0657da4fc703e      2018-01-14 14:33:31
# 3  00024acbcdf0a6daa1e931b038114c75      2018-08-08 10:00:35
# 4  00042b26cf59d7ce69dfabb4e55b4fd9      2017-02-04 13:57:51
#
#   order_delivered_customer_date order_estimated_delivery_date  media_nota  \
# 0           2017-09-20 23:43:48                    2017-09-29         5.0
# 1           2017-05-12 16:04:24                    2017-05-15         4.0
# 2           2018-01-22 13:19:16                    2018-02-05         5.0
# 3           2018-08-14 13:32:39                    2018-08-20         4.0
# 4           2017-03-01 16:42:31                    2017-03-17         5.0
#
#    maximo_nota
# 0          5.0
# 1          4.0
# 2          5.0
# 3          4.0
# 4          5.0

# %%
# Analisando o impacto de usar o máximo ao invés da média
avaliacao_ordem.groupby(['media_nota','maximo_nota'])['order_id'].count()
# Out:
# media_nota  maximo_nota
# 1.0         1.0            11316
# 1.5         2.0                8
# 2.0         2.0             3113
#             3.0               12
# 2.5         3.0               10
#             4.0               24
# 3.0         3.0             8094
#             4.0                9
#             5.0               33
# 3.3         4.0                1
# 3.5         4.0               17
#             5.0                8
# 4.0         4.0            18993
#             5.0               25
# 4.3         5.0                1
# 4.5         5.0               54
# 5.0         5.0            56955
# Name: order_id, dtype: int64

# %%
# Retirando quando maximo é igual a média
avaliacao_ordem[avaliacao_ordem.media_nota != avaliacao_ordem.maximo_nota].groupby(['media_nota','maximo_nota'])['order_id'].count()
# Out:
# media_nota  maximo_nota
# 1.5         2.0             8
# 2.0         3.0            12
# 2.5         3.0            10
#             4.0            24
# 3.0         4.0             9
#             5.0            33
# 3.3         4.0             1
# 3.5         4.0            17
#             5.0             8
# 4.0         5.0            25
# 4.3         5.0             1
# 4.5         5.0            54
# Name: order_id, dtype: int64

# %%
# Verificando o % dessas notas
avaliacao_ordem[avaliacao_ordem.media_nota != avaliacao_ordem.maximo_nota].shape[0]/avaliacao_ordem.shape[0]
# Out:
# 0.002047165891378594

# %% [markdown]
# **Podemos definir com o negócio que vamos utilizar o máximo da nota**

# %%
# Vamos considerar uma única coluna de nota
avaliacao_ordem['nota'] = avaliacao_ordem.maximo_nota

# %%
# E apagar as outras colunas para evitar confusão
avaliacao_ordem = avaliacao_ordem.drop(['media_nota','maximo_nota'],axis=1)

# %%
avaliacao_ordem.head(3)
# Out:
#                            order_id order_purchase_timestamp  \
# 0  00010242fe8c5a6d1ba2dd792cb16214      2017-09-13 08:59:02
# 1  00018f77f2f0320c557190d7a144bdd3      2017-04-26 10:53:06
# 2  000229ec398224ef6ca0657da4fc703e      2018-01-14 14:33:31
#
#   order_delivered_customer_date order_estimated_delivery_date  nota
# 0           2017-09-20 23:43:48                    2017-09-29   5.0
# 1           2017-05-12 16:04:24                    2017-05-15   4.0
# 2           2018-01-22 13:19:16                    2018-02-05   5.0

# %% [markdown]
# ### <font color='blue'>Agora sim vamos responder a pergunta da relação entre o atraso e a avaliação</font>

# %%
import datetime as dt

# %%
# Calculando o atraso na entrega
avaliacao_ordem['atraso'] =(avaliacao_ordem.order_estimated_delivery_date.dt.date - avaliacao_ordem.order_delivered_customer_date.dt.date).dt.days()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[235], line 2
#       1 # Calculando o atraso na entrega
# ----> 2 avaliacao_ordem['atraso'] =(avaliacao_ordem.order_estimated_delivery_date.dt.date - avaliacao_ordem.order_delivered_customer_date.dt.date).dt.days()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\accessors.py:580, in CombinedDatetimelikeProperties.__new__(cls, data)
#     577 elif is_period_dtype(data.dtype):
#     578     return PeriodProperties(data, orig)
# --> 580 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
avaliacao_ordem['atraso'] = pd.to_timedelta(avaliacao_ordem.order_estimated_delivery_date.dt.date - avaliacao_ordem.order_delivered_customer_date.dt.date).dt.days

# %%
# Marcando entregas que tiveram atraso com uma marcação (flag)
avaliacao_ordem['flag_atraso'] = avaliacao_ordem.atraso.apply(lambda x: 1 if x < 0 else 0)

# %%
# Verificando novamente a base
avaliacao_ordem.head(3)

# %%
# Verificando a nota quando existe atraso e quando não existe atraso
avaliacao_ordem.groupby('flag_atraso')['nota'].mean()

# %%
# Analisando os atrasos em relação a média das notas
avaliacao_ordem.groupby('atraso')['nota'].mean().plot();

# %%
import matplotlib.pyplot as plt

# %%
# Melhorando o gráfico e visualizando a quantidade de registros em cada dia
fig, ax = plt.subplots(figsize=(10,6))

base2 = avaliacao_ordem[(avaliacao_ordem.atraso > -30) & (avaliacao_ordem.atraso <= 50)]

media_notas = base2.groupby('atraso')['nota'].mean()
qtd_avaliacoes = base2.groupby('atraso')['nota'].count()

ax2 = ax.twinx()


ax.plot(media_notas.index, media_notas.values, linewidth=2.0)
ax2.plot(qtd_avaliacoes.index, qtd_avaliacoes.values, linewidth=2.0,c='r')


plt.show()

# %%
# Será que podemos agrupar os atrasos?
def agrupa_atraso(atraso):
    if atraso <= -30:
        return '01. abaixo de 30 dias'
    elif atraso <= -20:
        return '02. entre 30 e 20 dias'
    elif atraso <= -10:
        return '03. entre 20 e 10 dias de atraso'
    else:
        return'nada disso aconteceu'

# %%
# Aplicando a função
avaliacao_ordem['grupo_atraso'] = avaliacao_ordem.atraso.apply(agrupa_atraso)

# %%
# Verificando a média das notas por faixa de atraso
avaliacao_ordem.groupby('grupo_atraso')['nota'].mean().plot.bar();

# %%
# Usando a função já pronta apenas para adiantar a escrita do código
def agrupa_atraso(atraso):
    if atraso < -20:
        return '01. Mais de 20 dias de atraso'
    elif atraso < -15:
        return '02. Entre 15 e 20 dias de atraso'
    elif atraso < -10:
        return '03. Entre 10 e 15 dias de atraso'
    elif atraso < -8:
        return '04. Entre 8 e 10 dias de atraso'
    elif atraso < -6:
        return '05. Entre 6 e 8 dias de atraso'
    elif atraso < -4:
        return '06. Entre 4 e 6 dias de atraso'
    elif atraso < -2:
        return '07. Entre 2 e 4 dias de atraso'
    elif atraso < 0:
        return '08. Entre 1 e 2 dias de atraso'
    elif atraso == 0:
        return '09. Entregue na data'
    elif atraso <= 2:
        return '10. Entre 0 e 2 dias antes do prazo'
    elif atraso <= 4:
        return '11. Entre 2 e 4 dias antes do prazo'
    elif atraso <= 6:
        return '12. Entre 4 e 6 dias antes do prazo' 
    elif atraso <= 8:
        return '13. Entre 6 e 8 dias antes do prazo' 
    elif atraso <= 10:
        return '14. Entre 8 e 10 dias antes do prazo' 
    elif atraso <= 15:
        return '15. Entre 10 e 15 dias antes do prazo' 
    elif atraso <= 20:
        return '16. Entre 15 e 20 dias antes do prazo' 
    elif atraso <= 30:
        return '17. Entre 20 e 30 dias antes do prazo' 
    elif atraso <= 40:
        return '18. Entre 30 e 40 dias antes do prazo' 
    elif atraso > 40:
        return '19. Mais de 40 dias antes do prazo' 
    else:
        return '20. Verificar'

# %%
# Aplicando novamente a função
avaliacao_ordem['grupo_atraso'] = avaliacao_ordem.atraso.apply(agrupa_atraso)

# %%
# Visualizando a base
avaliacao_ordem.head(3)

# %%
# Verificando as avaliações que não conseguimos analisar a data
avaliacao_ordem[avaliacao_ordem.grupo_atraso == '20. Verificar']

# %%
# Podemos retirar da base as linhas que não são do nosso interesse
avaliacao_ordem = avaliacao_ordem[avaliacao_ordem.grupo_atraso != '20. Verificar']

# %%
# Analisando a média das notas por faixa de atraso
avaliacao_ordem.groupby('grupo_atraso')['nota'].mean().plot.bar();

# %% [markdown]
# **Depois que você já visualizou essa informação, pense na melhor maneira de apresentar**

# %%
# Salvando em uma variavel
base_nova = avaliacao_ordem[(avaliacao_ordem.atraso >= -10) & (avaliacao_ordem.atraso <= 10 )]

# %%
# Visualizando graficamente
base_nova.groupby('grupo_atraso')['nota'].mean().plot.bar();

# %%
import numpy as np

# %%
valores_grafico = base_nova.groupby('grupo_atraso')['nota'].mean()

# %%
# Melhorando a visualização
fig, ax = plt.subplots(figsize=(8,5))

x = np.arange(0,len(valores_grafico))

ax.bar(x,valores_grafico.values,color='tab:gray')

for i in range(0,len(valores_grafico)):
    ax.annotate(round(valores_grafico.values[i],1),(x[i],valores_grafico.values[i]),ha="center",xytext=(0,10),
               textcoords="offset points",c='tab:gray',fontsize=12,fontweight='bold')

ax.set_xticks(x)
ax.set_xticklabels([-10,-8,-6,-4,-2,0,2,4,6,8,10])
ax.yaxis.set_visible(False)    
    
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.annotate('avaliação média',(x[-1],valores_grafico.values[-1]),ha="left",xytext=(20,-15),
               textcoords="offset points",c='tab:gray',fontsize=12,fontweight='bold')
ax.annotate('entrega atrasada <<',(x[0],0),ha="right",xytext=(-20,-15),
               textcoords="offset points",c='tab:gray',fontsize=12,fontweight='bold')
ax.annotate('>> entrega adiantada',(x[-1],0),ha="left",xytext=(+20,-15),
               textcoords="offset points",c='tab:gray',fontsize=12,fontweight='bold')
ax.annotate('entrega no prazo',(x[5],0),ha="center",xytext=(0,-35),
               textcoords="offset points",c='tab:gray',fontsize=12,fontweight='bold')

plt.show()

# %% [markdown]
# ### <font color='blue'> 3. Como posso saber que as avaliações realmente reclamavam da entrega? </font>

# %%
# Verificando novamente a nossa base já tratada
base_nova.head(3)
# Out:
#                            order_id order_purchase_timestamp  \
# 0  00010242fe8c5a6d1ba2dd792cb16214      2017-09-13 08:59:02
# 1  00018f77f2f0320c557190d7a144bdd3      2017-04-26 10:53:06
# 3  00024acbcdf0a6daa1e931b038114c75      2018-08-08 10:00:35
#
#   order_delivered_customer_date order_estimated_delivery_date  nota  atraso  \
# 0           2017-09-20 23:43:48                    2017-09-29   5.0     9.0
# 1           2017-05-12 16:04:24                    2017-05-15   4.0     3.0
# 3           2018-08-14 13:32:39                    2018-08-20   4.0     6.0
#
#    flag_atraso                          grupo_atraso
# 0            0  14. Entre 8 e 10 dias antes do prazo
# 1            0   11. Entre 2 e 4 dias antes do prazo
# 3            0   12. Entre 4 e 6 dias antes do prazo

# %%
# E a base de avaliações
avaliacoes.head(3)
# Out:
#    index                         review_id                          order_id  \
# 0      0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                 None                   None
# 1             5                 None                   None
# 2             5                 None                   None
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24

# %%
# Pegando os ids das ordens entre 10 e 5 dias de atraso (as 3 primeiras colunas)
ids = base_nova.loc[base_nova.atraso <= -5,'order_id']

# %%
# Verificando as avaliações desses pedidos
avaliacoes.loc[avaliacoes.order_id.isin(ids),'review_comment_message']
# Out:
# 32       Sempre compro pela Internet e a entrega ocorre...
# 39                            Nada de chegar o meu pedido.
# 45                                                    None
# 106                                                   None
# 168      Comprei o produto dia 25 de fevereiro e hoje d...
#                                ...
# 99091                          Ainda nao recevi o produto.
# 99094    Gostaria de saber porque meu produto ainda não...
# 99098                                muito bom! recomendo!
# 99144                                                 None
# 99174                                                 None
# Name: review_comment_message, Length: 2078, dtype: object

# %%
# Visualizando esses comentários
for i in avaliacoes.loc[avaliacoes.order_id.isin(ids),'review_comment_message']:
    print(i)
# Out:
# Sempre compro pela Internet e a entrega ocorre antes do prazo combinado, que acredito ser o prazo máximo. No stark o prazo máximo já se esgotou e ainda não recebi o produto.
# Nada de chegar o meu pedido.
# None
# None
# Comprei o produto dia 25 de fevereiro e hoje dia 29 de marco não fora entregue na minha residência. Não sei se os correios desse Brasil e péssimo ou foi a própria loja que demorou postar.
# None
# Não posso! Estou aguardando a chegada do produto que comprei!Logo que isso aconteça, terei minha opinião formada!
# Comprei dois produtos e recebi somente um. Mandei dois emails para a loja e não tive nenhum retorno. Estou insatisfeita.
# Até agora nao recebi.Comprei este aparelho por questao de saude,portanto nao recomendo esta loja.
# comprei um produto para ser entregue por essa loja
# e ainda não recebi
# pois assim já se passou a data de entrega
# None
# Até agora não recebi nada, a colcha estava prevista para anteontem(18/12) e até agora nada
# None
# None
# None
# Até o momento eu n recebir o produto
# Não recebi o produto.e agora?
# None
# Preciso de uma previsão.
# Recebi outra boneca, quero devolver e não consigo contato! Jamais compraria novamente dessa loja!
# Estou esperando há mais de vinte dias e ainda não recebi meu produto e não consigo nenhuma informação.
# Gostei muito do que comprei com vcs muito obrigada breve farei outras compras vanda
# None
# Produto não foi entregue!
# Muito ruim, não veio um produto e o outro veio errado..
# Otimo material bem resistente espaçosa 👏👏👏 gostei!
# Sem pontualidade não da satisfação ao cliente.
# None
# Não posso dar opinião sobre produto pois não recebi, sobre a loja eu não recomendo, pois atrasa as entregas.
# None
# NÃO RECEBI O PRODUTO, O PRODUTO CONSTA COMO ENVIADO PARA O CORREIO DE RIBEIRÃO PRETO. O CORREIO NÃO RECEBEU O PRODUTO. ENVIE VARIAS MENSAGEM PARA A targaryen E NÃO OBTIVE. ESTA targaryen ESTA SUJANDO SEU NOME
# Vcs tá deixando a desejar comprei produtos com vcs e vcs demora entregar e ainda cancela o pedido sem autorização
# atendeu as expectivas
# Já entrei em contato com a lannister pelo telefone e eles me falam q vai mandar o link direto com o parceiro pra eu saber detalhes da entrega da conta e esse link n veio. Péssimo suporte ao cliente
# ótima
# Ainda não recebi o produto... varios dias que fiz a compra. entrega demorada pelas compras que faço online, ainda estou aguardando a entrega
# None
# None
# quero o meu produto
# None
# To esperando até agora nunca recebi nenhum relógio eu comprei não recomendado essa loja
# no site dizia que chegaria até 13/03 e ainda não chegou!
# Não recebi até agora a mercadoria.
# A empresa prestou ótima assistência, o produto chegou em ótimo estado.
# Minha avaliação ta sendo esta pq aqui aparece q recebi o produto e ainda não chegou em casa.Por favor, queria saber o q está acontecendo ???
# Atenciosamente,
# Juliana
# o produto nao poder ser avaliado ainda nao recebi
# None
# Simplesmente não recebi o produto
# None
# None
# Eu comprei um celular smartphone , não chegou não recomendo comprar nesta loja targaryen e lannister porque não chegou meu produto. Eu comprei está data,07/06/2017. Era pra chegar no dia .05/07/2017.
# produto em atraso.
# Estou aguardando espero que chegue logo
# PRODUTO NÃO ENTREGUE COM MUITO ATRASO E SEM PREVISÃO!!!!!
# PRECISO DE UM RETORNO COM URGENCIA.
# Foi a segunda vez que tentei comprar com essa loja e o pedido não foi entregue no prazo.
# amei
# None
# Ainda não recebi o produto. Apesar da greve dos caminhoneiros, os demais produtos referentes a este pedido (e a outros) já foram entregues. Será preciso que a loja verifique junto à transportadora...
# Comprei e paguei o produto ha mais de 20 dias e ainda não recebi o mesmo.
# None
# None
# Fiz a compra e meu pedido não chegou e dar como entregue!!!
# Ao efetuar rastreio consta em trânsito a 19 dias
# Excelente produto
# ruin
# None
# None
# Quero meu dinheiro de volta
# Tive que retirar no correio, se tivesse sido informada que não me entregaria em casa não teria feito o pedido...
# O produto ainda não foi entregue. Já realizei compras mais recentes na lannister, porem i produto deste pedido ainda não foi entregue.
# None
# Produto ainda não foi entregue, mas deixo essa opinião aqui como uma observação até a expiração da data.
# None
# não recebi meu produto e não obtive nenhuma resposta ainda
# Preciso de retorno de vcs, o pq de não ter chego o meu pedido.
# otimo
# Espero um retorno!
# Nem tentaram entregar o produto pois os dias e horários que constam no sistema eu estava em casa, além de não terem deixado nenhum comunicado na caixa dos correios de meu prédio inf tentativa entrega.
# Sempre comprei no site e fique muito satisfeito infelizmente pela primeira vez aconteceu esse imprevisto
# Espero que o problema seja resolvido em breve pois preciso da mercadoria
# None
# None
# None
# Não me entregaram o pedido tive que ir buscar no correio.
# E a segunda vez que pago frete é mandam eu ir retirar nos correios ,eo frete serve p quê?
# None
# Não responde as solicitações de atendimento.
# Já venceu a data limite para a entrega do produto, mas ainda não foi entregue para mim a minha compra. Ainda estou aguardando. Espero que chegue na segunda-feira.
# Recebi um, a compra foram de 2, está faltando 01.
# None
# COM O PÉSSIMO SERVIÇO DE ENTREGA NAS COMPRAS ATRAVÉS DA INTERNET, VOU CANCELAR TODAS AS COMPRAS. NÃO ESTOU SATISFEITO COM O ATENDIMENTO NA ENTREGA DOS PRODUTOS COMPRADOS. PEÇO PROVIDÊNCIAS.
# não recomendo pois não entregou no prazo e não consigo falar com eles, é muito ruim a targaryen
# None
# Realizei a compra e não consigo rastrear o objeto e tampouco saber onde ele está e nem previsão de sua chegada. Porém, a compra já veio na fatura do meu cartão. Lamentável.
# None
# Fiz o pagamento, já faz mês e não recebi o meu produto, estou indignado pois dependo deste para atender uma pessoa que precisa ficar constantemente com uma central de ar ligada.
# OTIMA, OS PRODUTOS CHEGAM PERFEITOS E SEMPRE NO PRAZO, A UNICA COISA QUE ACHO CARO E O FRETE.
# None
# None
# None
# None
# O produto comprado , chegou nos correios , mais os correios mandaram a cartinha de confirmaçao que o produto estava na unidade , depois do prazo . Poderia fazer o envio do produto de novo.?
# não recebi o produto, mais de 1 mês de espera.
# Comprei uma manta lilás e me enviaram uma cor goiaba,odiei a compra,era um presente e acabei nao dando o presente,e joguei no lixo.Que falta de profissionalismo, pelo jeito o vendedor e bem amador.
# não consigo rastrear meu produto.
# muita demora pra entregar
# atraso na entrega da mercadoria,não cumpre prazo determinado.
# Faz dois dias que o prazo da entrega venceu e o produto ainda não chegou, inclusive já foi pago parcela no cartão de crédito.
# Não recebi os produtos, quero meu dinheiro de volta.
# Por favor me reembolsar
# Sem palavras
# Péssimo não me deram nenhuma informação nem código e pior não me entregaram
# None
# pela segunda vez aconteceu problema em compra via internet. Primeiro foi com um climatizador que me mendaram com voltagem divergente.
# Agora com pedido feito na segunda semana de março e aainda nao en
# None
# O produto não foi entregue!
# Sei que o atraso da entrega ocorreu em virtude da paralisação.
# None
# Não recomendo a referida loja
# Produto não entregue. Prazo expirado.
# Estou muito insatisfeito com essa loja targaryen, já paguei o pelo produto e o mesmo não foi entregue no prazo, quero que entregue meu produto com urgência!!! Espero que a targaryen e stark resolvam isso.
# Além de não entregarem.não fui avisada nem reembolsada.
# None
# Vcs são todos enrolados não teem respeito com p cliente até hoje meu produto não chegou só sabem mentir entregar que é bom nada mais de 20 dias e não me entregaram nada
# Não recebi meu pedido, já tendo passado varias dias do prazo máximo estipulado, sem contar que a lannister nunca respondia minhas mensagens, então considero a empresa péssima.
# muito bom comprar aqui
# realizei a compra e no site tinha uma data para entrega só que essa data não foi cumprida
# produto atrasado sem resposta da loja
# None
# None
# O produto foi roubado do veículo dos correios. O vendedor reenviou um novo produto.Ainda não recebi, por isso estou avaliando a atitude da loja em me contactar e apresentar uma solução.
# Comprei com entrega prevista para ate 29/12 e não recebi, fui a uma loja americana e foi informado q o produto saiu de BH dia 11 e chegou no RJ dia 17.. até dia 30 não havia recebido nenhum e-mail .e
# None
# Sempre comprei nessa loja, espero que seja somente um falha dos correios, tenho certeza que resolvera essas situação do meu produto.
#
# None
#  Estou a dias esperando a mercadoria , já fui no correios , e não deixaram retirar !!!
# None
# valeu
# muito bom.
# None
# O prazo de entrega era dia 27/03/2018 hoje dia 29/03/2018 e ainda não recebi o produto!
# None
# Tesouras afiadas em perfeito estado , design bonito e super faceis de manusear
# None
# Não recebi a mercadoria...ESTÁ MUITO ATRASADA A ENTREGA...
# None
# None
# None
# None
# Recebi o e-mail perguntando se eu recebi meu produto, porem já passou do prazo de entrega e ainda NÃO recebi meu produto, e diz que se eu não responder o e-mail seria dado como produto entregue.
# None
# None
# None
# Não recebemos o produto
# None
# A informação de que o produto chegou não procede. A previsão de que seria entregue dia 16/03, porém o produto apesar de já ter a NF emitida não foi para a transportadora.
# Aguardo retorno.
# A capa é boa mais não encaixa perfeitamente no aparelho deixando parte da câmera e sensor de digital cobertos
# Exagerada a espera pra receber no produto.
# None
# Nao recebi o produto
# Infelizmente ainda não foi entregue!
#
# Primeira compra na loja parceira da stark e tive essa surpresa... devemos ficar mais atento a isso!
# None
# Prazo de entrega ultrapassado e nada do produto ou qualquer e-mail a respeito falando sobre o atraso e sua razão.
# None
# None
# demora na entrega
# None
# O PRODUTO AINDA NÃO FOI ENTREGUE NO PRAZO. O QUE EU FAÇO???
# A data limite para entrega do produto era 11 de abril. Já se passaram dois dias e a mercadoria não chegou. Quando receberei?
# None
# Pelo que parece o produto foi extraviado pelos correios / carga roubada , e simplesmente não tenho nenhuma explicação ou retorno da empresa. Já tentei contato com as lannister e protocolo.
# Não veio a embalagem certa
# Ainda nao recebi meu produto
# None
# None
# Comprei um patins dia 8/12/17 e até hoje não recebemos minha filha ficou sem presente de Natal porque vcs não conseguiram entregar aguardo o produto ou meu dinheiro de volta
# None
# O problema não é a loja, mas sim os Correios, que estão demorando demasiadamente para entregar os produtos.
# None
# Produto de boa qualidade
# None
# não esta sendo eficiente, me deram um prazo de entrega e ate agora nada
# Eu recomendo
# None
# None
# None
# None
# None
# Não recebi o produto
# Muito bom.
# Produtos ainda não chegaram; fui comunicado que extraviaram, e que será enviado novamente, mas, comprei para presentar, mas a data esta próxima, e o produto não chegara á tempo. no aguardo do produtos
# Até hoje nso5tecdbi eu produto e é bem satisfações
# não chegou ainda o meu produto .porquer
# None
# None
# None
# None
# Entrega atrasada!
# A negociação ocorreu conforme negociado com exceção de um pequeno atraso.
# None
# Não sei se por culpa da transportadora ou não, o fato é de que não recebi o produto ainda, e já está fora do prazo de entrega.
# demora, paguei um absurdo no frete ainda não chego, eu reclamei para correio para a lojas amiricanas, o correio falo q não pode faser bada q eu tenho q esperar, ja passo do prazo de entrega
# None
# None
# None
# Produto não entregue
# Loja muito ruim
# Meu produto não chegou ainda .
# Prazo excelente !!
#
# estou insatisfeita em relação a entrega que não foi entregue ainda,já paguei a parcela do produto e não o recebi ainda.
# Não recebi
# não foi entregue
# Considerando o site stark nunca tive problema algum e recomendo ao meus amigos porém está empresa que está atendendo com a venda do produto deixou a desejar com o prazo de entrega... Será q chega?
# Não chegou
# None
# Eu não tenho como avaliar o produto porque não chegou na minha residência ainda eu espero uma posição da loja sobre os correios quero cancelar a compra estorno do cartão
# None
# None
# Nunca vi demorarem tanto para entregar um cartucho
# Está vindo da China ?
# Ainda não recebi meu produto, não sei porque?
# Sempre comprei nas Lojas lannister e entregaram no prazo. A Loja e terceirizada, mais comprei confiando nas Lojas lannister.Espero resposta.
# O prazo encerrou no dia 10/11/2018 e até presente data não foi entregue.
# None
# None
# Muita demora na entrega.
# None
# O prazo não foi cumprido
# None
# Péssima entrega fiz a compra no dia 13/02 e até hoje 18/03 não recebi o produto
# None
# None
# Estou esperando há quase um mês, uma falta de respeito ao consumidor
# None
# Produto chegou com defeito na pulseira, entrei em contato pra fazer a troca e até agora não me responderam. Demorou pra chegar, e eu tive que fazer retirada nos correios, não entregaram em minha casa.
# Produto não entregue
# Ainda não recebi meu produto, kit maternidade, o que preciso receber com urgêncica, pois estou para dar a luz a qualquer momento. Sempre compro pelo baratheon e nunca antes tive problemas com o prazo.
# None
# o meu pedido estava para ser entregue até 15/08/2018, mas até agora não recebi.
# None
# None
# None
# None
# Meu ponto de vista o produto é muito bom ele realmente faz o que diz ele retira todos os pelos do local aplicado não irrita a pele deixou a pele macia.. Recomendo o produto muito bom compensa comprar.
# Faz mais de 45 dias que comprei omproduto e não chegou .
# Produto estava com prazo de entrega para 13/04. No momento está em dois dias de atraso. Necessário verificar o porquê do atraso e regularizar entrega. Presente de aniversário pendente de entrega.
# None
# None
# None
# Até hoje 28/3 ainda não recebi o produto. Não sei se vou receber ou terei que entrar com processo para receber meu dinheiro de volta. Imagine se tivesse dependendo disto?
# None
# não recebi o produto.
# Após aguardar mais de 1 mês da data do pagamento, o pedido foi cancelado pelo sistema. Fiz uma reclamação no site e até agora não recebi resposta. Uma falta de respeito e desonestidade.
# Muita demora na entrega
# Foi a 1º compra com o parceiro targaryen da lannister, acho que está tendo problemas do CORREIOS, por enquanto não posso avaliar.
# None
# None
# não posso recomendar pois não recebi o produto
# O prazo para meu produto chegar era até o dia 10/04/2018 e até agora não recebi.
# Não recebi ainda meu produto.
# None
# O produto estava marcado para dia 12/12 e até agora não recebi
# É uma pena não ter chegado antes do Natal
#  Espero que chegue até o ano Novo!
# Não sei se foi por causa dos correios, mas o fato é que nem sei se vou receber o produto, pois o lojista não entrou em contato comigo, mesmo após reclamação.
# None
# Pagamos para a entrega ser feita em nossa residência e não para retirarmos nos Correios.
# É uma loja muito boa mais infelizmente demora pra entregar
# Ainda não recebi meu produto... chateada
# Não recebi meu produto ainda
# None
# Ate o momento alnada do meu pruduto, gostaria de saber quando que vou receber...
# Quero o cancelamento.
# ATE AGORA NÃO RECEBI O PRODUTO APESAR DE JÁ TER PAGO
# None
# None
# Foi ótima o atendimento sem comparação muito bem atendido nota 10 pra empresa muito obrigado pelo atendimento no geral
#
# Bom Natal e feliz ano Novo
# Bom dia , o produto não foi entregue e no rastreamento ainda colocaram que não tinha ninguém em casa. O que é uma mentira, porque ficou gente em casa o dia todo. Espero que seja entregue
# NÃO RECEBI AINDA O PRODUTO...AGUARDANDO.
# None
# None
# entrega no praz, produto entregue com sucesso
# None
# None
# Comparei uma banheira e não recebi no prazo combinado tenho pressa pois meu neto está pra nascer antes de eu fazer a compra eu me certifiquei que iriam me entregar na data certa mais não recebi
# ja passou o prazo de entrega e ainda nao recebi o pedido
# Produto corresponde ao pedido. Ótima qualidade.
# None
# Produto não entregue. Ainda aguardando, porém, já desapontado com o serviço de entrega.
# pessimo atendimento mercadoria chegandoatrazada vou fazer uma propanda pra nimguem mais comprar ai
# None
# None
# None
# Ainda nao recebi o produto.
# None
# Um absurdo!Sempre comprei no site das lannister...nunca tive problema,mais essa última compra está fazendo vergonha...apesar de dar um prazo enorme para entrega q foi quase dois meses ainda não chega
# O produto não foi entregue!
# Gostaria de saber quando vou receber meu pedido, porque eu acho que se veio entregar a nao tem pra receber, deve haver outras tentativas. Aguardo uma posicao.
# None
# None
# Não entregou no prazo e até agora não retornou meus contatos. Lamentável.
# Produto pago, mas não houve entrega até agora.
# Incomodou um pouco por conta do atraso. Aproximados 20 dias. Mas valeu.
# Só realizei a compra pq chegava antes do Natal e até agora nada de chegar.
# Ainda não recebi
# None
# None
# americana sempre entrega rapida e tudo certo agadeço e parabens pela competencia
# ainda estou esperando o produto e nada...
# Ele não é um mini cajon, é um shaker, ou seja, um chocalho que imita o cajon. Péssimo.
# None
# Não recebi o produto , e não tive nenhum retorno da loja para saber do produto .
# AINDA NAO RECEBI O PRODUTO
# sem comentarios ja disse o q penso em email anterior , só coloquei uma estrela p poder responder a enquete, p mim daria menos 5 estrelas
# Estou aguardando uma posição da loja em relação a disponibilidade do produto
# bom
# Até agora tudo que comprei pelo sate da lannister, recebi certo.Estou aguardando a entrega da targaryen..que tinha previsão para o dia 26 e até agora não chegou.
# Esperando chegar ainda e nada de chegar ja paguei
# Não recebi o produto no prazo prometido.
# None
# None
# None
# None
# None
# None
# None
# None
# O Produto esta com a ntrega atrasada,mesmo ,mesmo com o prazo de 1 mes para entrega.
# Enviei e-mail e tambem não obtive retorno.
# Comprei o produto em outra loja, devido a necessidade de utilização.
# None
# None
# Entrega foi programada para 12/04/18. Em 19/04/18 ainda não foi entregue. Tentei estabelecer contato direto com a transportadora targaryen, mas não tive retorno até o momento. Reavalio quando receber.
# None
# Resolveram meu problema é meu produto foi entregue em perfeito estado
# precisava urgente do equipamento para uma pesquisa, porém passou do prazo de entrega e nao me dão nenhuma resposta!!!
# Comprei mei produto dia 28 e até hoje nao foi entregue
# Fui até os Correios do outro lado da cidade buscar a encomenda, a caixa veio com as especificações corretas do produto mas ele não possui HD de 1.5 tb veio hd de 290 GB. Temos que resolver
# Otimo. Top de linha
# foi entregue so q nao esta funcionando
# fora a demora esta ok
# Xxx
# estou aguardando
# None
# Quando meu produto estiver entregue posso avaliar.
# Todas as etapas de entrega tiveram um problema, o objeto chegou com atraso em tudo e até agora consta que não chegou à unidade do rio de janeiro, sendo que era pra eu ter recebido o produto no dia 10
# Não recebi o produto ainda
# None
# None
# None
# Meu produto ainda não foi entregue.
# Pode ter sido por falta de gasolina no pais mas mesmo assim preciso de uma posição de vocês.
# None
# None
# Vc paga um frete caro e não entregam na sua casa.
# To esperando até agora meu relógio, mais 2 dias cancelo a compra.
# None
# None
# A loja não respondeu minha pergunta e não recebi meu produto. Comprei na stark e não na targaryen.
# Meu produto era para ter chegado ate dia 15/08, mas ate hoje não recebi.Houve algum problema?estou preocupada.
# Não recebi o produto nem tenho notícias do mesmo.
# None
# O tapete não é tao peludo quanto a foto... ele é bem fino e os pelos bem baixos.
# Nao recebi o produto
# Ja passou o prazo e não recebi o produto.
# Até o momento, não me dizem nada. Isso é péssimo p a americana. Trata o cliente pessimamente mal.
# Uma loja que só pensa em pegar o dinheiro do cliente, mas não entrega mercadoria.
# Produto não foi entregue
# None
# None
# Informado que o produto chegaria até dia 19/04, sendo que foi comprado no início de abril. Já é dia 23/04 e nada do meu produto chegar...
# Novo, lacrado, otimo atendimento, recomendo
# Infelizmente, o produto não chegou até o momento.
# Estou aguardando alguma informação concreta das lannister ou do fornecedor quanto a esta situação.
# Por gentileza, me dêem algum retorno.
# Não entregou no prazo por isso a avaliação ruim. Ainda não recebi o produto
# None
# None
# o produto não foi entregue, foi pelo correio e não receberam no local. Não consigo falar na loja para resolver
# O envio ocorreu rapidamente, porém, ainda não recebi o produto. Está parado desde 25|02|2018 nos Correios. E não sei ao certo a localização.
#
# Produto não entregue no prazo determinado.
# Aguardando produto.
# None
# None
# Sem comentários.
# Quero saber porque tanto atraso na minha encomenda, porque deram previsão de entrega para o dia 23/4 até hoje nada
# Comprei faz meses esse relógio e até a presente data não recebi e me sinto lesado e prejudicado pois comprei com antecedência para dar de presente e não chegou até agora!
# O pedido foi realizado dia 18/04. O prazo de entrega era dia 10/05 e até hoje, dia 14/05 o produto não chegou.
# None
# Os garfos e facas adquiridos demoraram muito para chegarem e vieram sem a NF, jogados numa caixa deformada e os utensílios todos de baixa qualidade, vieram amassados e com as pontas dos garfos tortas.
# None
# None
# Não recebi o produto
# None
# Super atrasado a entrega , prometeram em 12 dias e até agora não chegou 02/01/2018 era um presente , agora já perdeu o sentido
# o produto não chegou
# Não tenho como avaliar um produto que não recebi.
# Produto fora de prazo, não deram satisfação alguma, compra realizada no final do mês passado, tendo passado dois dias da data de entrega e o produto nem saiu pra transporte.
# Fiz a compra no início de setembro e até hoje 11 de outubro não recebi o produto aguardando uma solução da empresa
# None
# Aré a presente data não recebi a mercadoria, o que me surpreendeu , uma vez que a lannister.com sempre cumpre os prazos. Em alguns produtos houve até antecipação .
# Estou muito chateado pois ainda não recebi e não tenho nenhuma satisfação a respeito, se vcs não resolverem logo com o envio viu procurar meus direitos pois já paguei.
# Produto não entregue. Gostaria de saber como proceder para ressarcimento ou entrega do mesmo.
# None
# None
# O produto ainda não chegou na minha casa.
# None
# Ainda não recebi minha entrega comprei TV muito antes pela stark e ainda esse produtos que já vai fazer mês não chegou..
# None
# não me entregou no prazo cancelei a compra.
# Não recebi o produto.
# A marca cassio sempre foi excelente, estou aguardando a chegada do produto para fazer a reavaliação do Revendedor.
# nao recebi o produto acredito ser problema dos correios prazo de entrega expirou
# None
# Ainda não recebi o produto
# Falta de respeito com o cliente
# ainda não recebemos o produto.
# None
# A OPÇÃO DE RASTREIO DO PRODUTO É MUITO VAGA NÃO DA INFORMAÇÕES REAIS DE ONDE SE ENCONTRA O PRODUTO. O MINIMO SERIA TER COMO ACOMPANHAR O PEDIDO
# None
# Me parece que os Correios perderam o produto. Não posso culpar a loja. Só espero que possam cobrar os Correios e reenviar o produto da maneira mais rápida possível, uma vez que tenho necessidade dele.
# None
# None
# None
# Não respeitou o prazo da entrega
# None
# O prazo de entrega foi estipula para 19 de julho a compra foi feita em 26 de junho e ainda não foi entregue, ou seja razo de entrega não foi cumprido conforme anunciado no site na hora da compra.
# None
# None
# None
# O produto não foi entregue ainda,e nem uma comunicação pela empresa sobre a entrega..
# None
# Ainda não recebemos o produto
# Quero saber quando entregarão o produto? Era presente de aniversário e não chegou na data.
# Pedi e não recdebi o produto mudaram duas vezes a data da entrega e não recebi o produto e gostaria de saber vou ficar no prejuizo ?????
# O produto não foi entregue, razão pela qual afirmo que não foi cumprido o acordado. Não recomendo está empresa. Por fim desde já solicito a devolução do valor pago devidamente corrigido.
# Infelizmente, a empresa trabalha com os Correios, que nunca cumpre os prazos de entrega.
# None
# quero meu dinheiro de volta
# Primeira vez que faço um pedido pela Internet e após 37 dias ainda não recebi o produto.Era pra dar de presente sendo que a dia do aniversário já passou há muitos dias. Será a última compra nas Americ
# Não recebi ainda os produtos por incompetência dos correios, não tem como avaliar da maneira que vocês pediram. Acho que vocês deveriam mudar a pesquisa. Tipo: se não, Porque?
# Produto não chegou no prazo
# None
# Falta de compromisso com o cliente
# poderia melhora
# a entrega estava prevista para 29/08 porem ate 31/08 não chego,mais creio que próxima semana chegue,ficarei no aguardo depois avalio mais.
# None
# Tive que cancelar a maioria das minhas encomendas, só gostaria de ter sido procurado pela equipe de atendimento não só por e-mail.
# Sei que em grande parte da culpa foi dos correios.
# None
# Não Recebi o produto ainda!!
# None
# Gostei do produto comprei de presente
# Pagamos caro para receber em casa (frete de R$95,00) e ainda não recebi o produto, não consigo retirar nos correios pois não deixaram o papel de retirada na minha casa. INSATISFEITA!!!!!
# None
# Comprei o relogio para o dia das mães e até hoje o mesmo não chegou.
# None
# None
# Meu produto não foi entregue ainda, espero que seja!
# Não recebi e estou muito chateada.
# None
# O produto além de não ser entregue, não consta nenhuma data para sua efetiva entrega.
# None
# Foi a primeira vez que comprei pela internet, mesmo desconfiada resolvi arriscar.Espero que meu problema se resolva o mais rápido possível,pra futuramente poder fazer novas compras.Aguardo resposta.
# Muito chateada pois já completou 30 dias que comprei meu produto e o mesmo ainda não chegou.
# Talvez por dificuldade nos correios
# Entrega no prazo, gostei do produto, recomendo!
# None
# None
# PRODUTO NÃO CHEGOU
# Não gostei desta compra pois a entrega atrasou além de ter um período muito extenso para entregar.
# AINDA NAO RECEBI MINHA MERCADORIA
# O PRODUTO NÃO FOI ENTREGUE, GOSTARIA DE SABER COMO VAI FICAR AGORA?
# None
# Entrega pelos Correios? É só dor de cabeça, porque não fazem entrega e nem sequer trazem o produto para a agência próxima de minha casa. Tenho que ir buscar longe de onde moro e não dão assistência
#
# Comprei e até agora nada de chegar, prazo pro dia 09, e até agora nem sinal.
# Ainda não tive retorna da loja targaryen, só tive retorno da equipe das lojas lannister que esta acompanhando o produto. Ainda aguardo!
# Comprei um simples pendente meia lua no site das lannister, vendido pela loja targaryen, em 09/março e até hoje, 14/abril, o produto não foi entregue. Não recomendo compra de produtos desta loja.
# ESSA LOJA É MUITO BACANA COMPRO MUITOS PRODUTOS NELA, MERECERIA UM BRINDE.
# None
# None
# Produto nao chegou
# None
# None
# Não recebi o produto.
# None
# None
# None
# None
# None
# A empresa não acompanha o rastreamento, desde o dia 1 de março encontra-se sem atualiazação na agência dos correios de Cajamar-SP, e somente o remetente pode abrir uma reclamação junto aos correios.
# None
# todos os outros produtos foram entregues no prazo. Porém esse está em atraso e tenho evento no dia 25/04 e estou contando com o material
# demora na entrega (ainda nao chegou fora do prazo)
# None
# Olá!
# Ainda não recebi o produto e o prazo informa para entrega seria para dia 04.06.2018, mais até o momento nada......
# None
# Deveria enviar este produto por uma empresa diferente do Correios, devido a empresa demorar na entrega e não liberar o produto no centro de distribuição.
# É lamentável o que está acontecendo,está muito difícil comprar pela internet. Sendo que a compra está paga,já debitada do meu cartão,e até agora não consigo usufruir do meu produto.Não tenho notícias!
# None
# Infelizmente minha compra ocorreu na época de greve dos caminhoneiros e por isso não foi entregue no prazo correto. Mas é uma excelente loja e voltarei a realizar futuras compras.
# Paguei o produto a vista, não recebi no prazo estipulado e não me enviaram nenhuma informação apos vencimento do prazo de entrega.
# None
# Péssimo
# None
# ainda aguardo meu produto
# O produto ainda não foi entregue
# None
# None
# None
# Atraso na entrega.
# Péssima loja
# Muito bom de confiança
# O produto chegou perfeito sem nenhum defeito com as medidas certas
# Chegou até 1 semana antes do prazo
# Super recomendo
# Comprei no dia 10/01. O prazo de entrega no momento da compra era de até 12 dias e até agora não chegou.
# Não recebi o produto o prazo terminou ontem.
# None
# N recebi o produto ainda, o prazo era pra ate o dia 8 e hoge é 10, na espera
# Não gostei muito ruim não compro mais nessa loja.
# None
# Meu pedido era pra ter chegado até no máximo dia 20 de março, hoje já é dia 22 de março e ainda não chegou!!! Estou bastante desepcionado com a loja.
# Não recebi o produto!
# A DATA DE ENTREGA ERA DIA 27/09/2017
# MAIS AINDA NÃO RECEBI MEU PRODUTO NA MINHA RESIDENCIA
# O produto era pra ser entregue até 23/01 e até o momento (03/02) ainda não recebi.
# None
# Não recebi meu produto até hoje é era um presente de casamento.
# capa protetora de celular igual a descrição, porém, o tamanho da capa e da pelicula de vidro veio maior doque o modelo descrito. super chateada por não receber o que era esperado.
# SEM INFORMAÇÕES SOBRE O PARADEIRO
#
# Estou esperando meu produto
# Não recomendo essa loja pra ninguém comprei o presente do meu filho no dia 23 de janeiro vai fazer um mês e nada ainda estão dizendo que o carteiro chamou e ninguém atendeu fiquei o dia inteiro emcasa
# None
# None
# correios informa que ate agora não chegou no cd da minha cidade, mas loja que entrega com o correio so se pode esperar isso mesmo
# Estou aguardando chegar para poder classificar o produto
# Meu pedido ainda não foi entregue, aguardo resposta.
# Não recebi meu produto. Não posso avaliar.
#
# A loja lannister é referência na entrega de seus produtos sempre comprei e recebo muito antes do prazo, mas esse parceiro, nãorecomendo.
# None
# None
# None
# Falta de atenção e respeito com cliente
# None
# paguei o produto e até agora não recebi, vou procurar meus direitos junto ao PROCON.
# Ainda não recebi. Estou aguardando a entrega do produto ou o cancelamento da compra.
# None
# None
# Não recebi meu produto e nem obtive ate o momento explicação para o atraso.
# Não tem opinião pois o meu produto não chegou até hoje marcado pra chegar até o dia 27 de setembro
#
# Alem do prazo de entrega bem extenso a mercadoria ainda encontra-se retida, sem atualização, completando hoje exatamente 30 dias que comprei a mercadoria.
# Descumprimento de entrega em produto alimentício
# Produto de qualidade. Somente a entrega efetuada através dos Correios demorou mais de 30 dias.
# A criança já está se formando e o produto ainda não chegou
# nas lannister gosto de comprar mas na targaryen
# nao da pq cancelei o pedido no mesmo dia e ate hoje nao tem nada resolvido pois foi no cartao e ja paguei a primeira
# None
# Até agora nada do produto ser entregue. O que eu devo fazer ?
# None
# Bom dia. Comprei cinco itens e recebi três, Xbox Entregue, dois jogos Entregue, um carregador Entregue. Falta um controle do xbox e uma capa. Estou esperando PACIENTEMENTE.
# Nunca chegou o produto
# O produto deveria ter sido entregue até 21/3 não chegou. Hj é dia 23/3 e até agora não tenho previsão alguma de entrega. Quero retorno sobre como ficará a situação!!!
# Prazo de entrega não cumprido.
# Não recebi meu pedido!
# O prazo para entrega é muito grande, ainda não recebi o produto, estou rastreando e estou aguardando chegar em uma agência para eu retirar, solicito uma ajuda junto aos correios sobre o caso. Obg.
# None
# Ainda não recebi o produto e nem fui comunicada a respeito do motivo do ocorrido. Qual a posição da lannister?
# A mercadoria ainda não chegou um absurdo, eu fiz uma compra no mercado livre saindo de são paulo mesmo lugar desse parceiro de vocês e a minha encomenda já chegou pelo pac e a de vocês nada.
# Não recebi até agora o produto.J Á MANDEI DOIS EMAILS SOLICITANDO INFORMAÇÃO E NÃO ME RESPOSDERAM NADA.
# Estou ainda aguardando o produto que estava previsto para ser entregue no dia 22/08/2017 e hoje dia 24/08/2017 não chegou ainda até o presente momento.
# aguardando a resolução do incidente pois ainda não recebi o produto...
# None
# Não recebi o produto até o momento.Estou insatisfeita.
# Uma vergonha comprar um produto e não o receber.
# Bom dia!estou insatisfeita com a demora
# Além de demorar, não chegou.
# None
# None
# o produto ainda não chegou, já passou do prazo de entrega
# Ainda não consegui receber o produto em minha casa.
# Talvez devido a greve dos caminhoneiros, ate agora nao recebi o produto.
# Preciso da cadeira com urgência, pessoa com deficiência .
# Comprei bem adiantado pois era o presente de aniversário do meu sobrinho e não chegou a loja entreou em contato apenas 1 vez e não me respondeu mais.
# Espero ainda receber o produto🙏🏻
# None
# None
# None
# Não posso opinar ,pois não recebi.
# Eu não sei o que está acontecendo, eu preciso do produto urgente e até agora não chegou. Tem mais de um mês
# None
# None
# Comprei 2 relógios e entregaram apenas 1. Aguardo posicionamento da loja qto a isso ou estorno do valor no cartão.
# None
# Ainda não recebi minha encomenda
# enviou pelos correios e ate agora nada
# Mercadoria em atraso e nenhuma satisfação foi dada,falta de compromisso com cliente
# Até no momento ninguém entrou em contato sobre o produto, não consigo rastrear o mesmo!
# None
# Atraso na entrega, até o momento nao recebi o meu produto.
# None
# Ainda não foi entregue o pedido e já passou do prazo da entrega. O status do pedido não era atualizado diariamente. Foi atualizado hoje que estava vindo para minha cidade, espero a entrega.
# Meu produto não foi entregue ainda. E o vendedor não me dar nenhuma satisfação eu já mandamei vários email msg de reclamação é até agora nada foi feito
# None
# Nao cumpre o prometido
# O produto não chegou na data e não recomendado é nem compro mais nenhum produto
# None
# None
# None
# None
# Bom dia, este produto já passou da data prevista de entrega, não recomendo está loja, aguardo retorno
# None
# Entrei em contato 2 vezes tentando verificar onde meu pedido estava que desde o dia 14 nao tenho atualizacao, e nem me foi respondido e ja passou a data limite, nunca mais!
# None
# Prezado senhor,
#
# não recebi o produto no qual já paguei.
# Favor retornar URGENTE!!!!
#
# Elói.
# None
# Demora muito entregar. Já passou o prazo e ainda não recebi minha encomenda.
# Deveriam contratar transportadora e não correio até o momento não recebi minha encomenda
# O prazo de entrega era até dia 26/03 e até hoje ainda não recebi o produto e já faz mais de um mês q pedi. Não recomendo
# None
# ainda não recebi meu produto e quero saber como anda a entrega. Estou pensando em cancelar a compra.
# None
# Meu pedido estava com data para entrega no dia 20/12/2017, recebi um email de confirmação de entrega mas ainda não recebi o produto.
# Comprei e nao recebi....
# Recomendo não comprar produtos que são entregue por outras empresas que não forem das lojas lannister.
# None
# None
# None
# quando liguei pra loja pra saber o porque meu produto ainda não tinha chegado o atendente foi muito grosso
# Este produto era para presentear minha esposa, infelizmente até a presente data não chegou.
# None
# None
# Não recebi o produto, solicito reembolso!
# None
# None
# nao recebimento
# None
# None
# Não recebi o produto, vou querer receber o dinheiro de volta
# None
# None
# None
# None
# DEMORA DIMAIS NA ENTREGA PEDIDO AVALIAÇÃO E O PRODUTO AINDA NEM CHEGOU
# None
# None
# Más ja cancelei.
# Poderia desfazer o cancelamento por favor
# None
# None
# Vcs são bons pra. Vender mas não dão suporte nenhum
# O CORREIO ME ENTREGOU SOMENTE UMA CORTINA SENDO QUE NA NOTA FISCAL CONSTAM DUAS E PEDI DUAS.
# None
# None
# None
# O cartucho "original HP" 60XL não é reconhecido pela impressora, consequentemente não funcionou. Além de ter chegado com atraso de mais de 15 dias do previsto. Preciso que seja trocado.
# Estou aguardando o correios e nada do produto queria dar para minha sobrinha no natal pois foi o que ela pediu de presente para o papai noel.
# O pedido era pra ter chegado dia 05/01 e até agora nada.
# None
# Acho muito fraca está loja.
# Quero o meu produto onde está?
# None
# Estou a espera do produto à dias .. E ainda não foi entregue.
# Comprei o produto no inicio de fevereiro e ainda não recebi e não houve posicionamento da loja
# None
# Estou esperando o meu produto já tem mais de 10 dias e ainda não chegou na distruidora de Juiz de Fora.
# None
# O produto estava com uma má qualidade,pensei que viesse melhor ...
# Infelizmente, virou regra no Brasil, o consumidor comprar, pagar e não receber o produto. Prazo tem que ser cumprido e, a responsabilidade é do vendedor.
# Produto recebido com conforme anunciado. Cliente satisfeito.
# None
# a entrega foi efetuada dentro do prazo previsto fiquei satisfeita.
# Não foi entregue o produto .
# Realizei a compra e o pagamento, o prazo venceu e nada do produto ser entregue, na verdade não foi nem enviado ainda. Péssimo!
# Meu produto nao foi entregue
# Comprei um relógio e não entregou , era previsto pro dia 06/06 , e voltou pra São Paulo
# até o momento não recebi meu produto
# None
# None
# Comprei dois produtos e ambos, mesmo enviados em dias diferentes, estão como em "dificuldade na entrega" segundo o rastreamento dos Correios. O que nunca me aconteceu antes.
# Ainda não recebi minha compra. Já passou do prazo previsto!
# Pessima está loja não enttaga o produto
# None
# O PRODUTO FOI ENCOMENDADO EM DEZEMBRO, COM PREVISÃO MÁXIMA DE ENTREGA PARA 06/01. NÃO RECEBI O PRODUTO NEM RECEBI NENHUMA SATISFAÇÃO ACERCA DO PROBLEMA.
# Merda de loja não entregou meu pedido
# o produto não chegou.
# Não recebi. Passou o dia de entrega.
# Não recebi o produto
# None
# O prazo de entrega não foi cumprida e só comprei para dar de presente para uma mãe que está prestes a ganhar bebê. Só comprei pelo site por conta da data de entrega 19/05, terá o parto sem a bolsa.
# None
# Comprei o produto no dia 19/01 após 30 dia eu ainda não recebi meu produto. Demora demais pra entregar, se tive comprado da china já estaria aqui.
# Ate a data de hoje nao foi entregue pois fui ate uma das lojas de vcs pea pedir uma solução nem o atebtende sobre me responder fizeram pra mim eu de bobo eu confiei na lojas aguardo resposta
# Produto com bom acabamento.
# Pois ate o momento nao fecebi a cacarola os demais itens que adquiri ja chegaram e ela nao. Alguem pode me dizer o motivo. Preciso muito dela....
# Produto bonito e confortável, porém não durma de unhas grandes nem sem esfoliar os pés, porque é frágil e puxa fio com facilidade.
# None
# None
# Meu pedido esta preso nos correios....
# Super fácil de colar e fica super lindo!
# None
# Não recebi o produto
# Meu produto não chegou. Qual a solução?
# O produto não é entregado no praZo
# Ainda estou a espera do meu produto
# None
# Não recebi o produto a causa do incêndio nos correios de indauatuba são Paulo
# Gostaria que me envia-se a mercadoria ou devolvesse meu dinheiro ia fazer mais compras mais fiquei com medo de não entregar
# A entrega ainda não foi efetuada.
# Foi cancelado o pedido no mesmo dia da compra recebi um email confirmado o cancelamento mais o produto foi entregue mesmo assim. Não aceitei o produto mais ainda está descontando em minha fatura
# Não recebi o produto
# Perdi totalmente a confiança nas compras on line dessa loja. Não recebi nem o produto nem respostas
# None
# um dos produtos teve um atraso mas geral veio certo entao recomendo
# Até o momento o produto não chegou na minha residência e a loja não entra em contato
# None
# Não recebi e ninguém me ligou. Falei por msg.e ninguém me respondeu
# None
# None
# Não foi uma boa experiência. Não consigo contato com vocês. E vou esta cancelando o pagamento, caso não entrem em contato.
# Recomendo, produto de otimo qualidade. Veio tudo correto; estou muito satisfeita!
# None
# None
# Não recebi o produto
# Fiz a compra em 07/12/17, ja passou o prazo de entrega, e aonde esta meu produto? Ficam pondo a culpa no correio, sendo que quem faz a minha entrega é uma pessoa conhecida, e ele me disse que não cheg
# ainda nao recebi o produto
# Eu só quero saber cadê meu pedido que não chegou ainda ? Pois já venceu o prazo
# None
# Boa noite, não recebi o produto. Correios nunca atualizou o código de rastreio e nem uma posição da loja até o momento.
# None
# Pelo site da lannister não dá pra acompanhar a movimentação do produto.
# Ainda não usei o produto.
# A encomenda demorou muito a chegar mas chegou em perfeito estado.
# Enviou o produto a mais de um mês, mas ainda não chegou e a loja nem um parecer me deu. Pode não ser culpa dela mas poderia acompanhar e fazer alguma coisa a respeito.
# Meu produto ainda não chegou comprei dia mês passado já estamos acabando o mês de agosto e ainda não chegou
#
# None
# Já paguei faz tempo, estou precisando é ainda não recebi os produtos
# Estou satisfeita com o produto.
# COMO DAR MINHA OPINIÃO?????
# NÃO RECEBI O PRODUTO ISSO JÁ É UMA MANEIRA DE SABER QUE ESTOU TOTALMENTE INSATISFEITA E IRRITADA.
# QUERO SABER QUAL SERÁ A PROVIDÊNCIA????
# não recebi a mercadoria...
# None
# Não recebi o produto
# AINDA NÃO RECEBI MEU PRODUTO, JÁ FAZ UM MÊS QUE COMPREI E AINDA NÃO RECEBI O PRODUTO
# None
# None
# None
# None
# None
# None
# None
# None
# Mias de 1 mês após a compra ainda não recebi o produto. Solicito devolução do valor pago.
# Ainda não recebi meu produto. O prazo já passou em dois dias e nada.
# None
# None
# None
# O produto já passou da data de entrega e não consigo saber o que aconteceu. Até agora nada.
# None
# None
# None
# Até o momento nao recebi o meu produto. Esta na hora de abandonar o correio que esta um lixo. Verifiquem com aqueles vadios dos correios se irao entregar ou nao o meu produto. Aguardo retorno.
# quero receber mminha compra
# Meu produto está atrasado e ainda não chegou
# Como posso avaliar algo que não recebi.
# Já paguei o produto e no status diz que o produto não chegou ainda na unidade da minha cidade.
# entrega para 21/12/2017.
# cadê o produto?fico no prejuízo?
# A gente só compra porque se ilude pensando que está comprando na lannister. Quando descobre que é com parceiros é tarde. Esse negócio de parceiros deve acabar.
# None
# Ainda não recebi
# Pela demora não recomendo a loja,pois já faz um que comprei e não me enviaram ainda e nem uma satisfação me deram.
# ja esta em atraso de 4 dias
# None
# None
# None
# Estou aguardando a entrega em minha casa em Paraibuna
# None
# None
# AIND ANÃO RECEBI O PRODUTO E PASSOU DA DATA DE ENTREGA
# None
# None
# None
# None
# None
# None
# paguei e já venceu a data de entrega e ainda não recebi.
# None
# Pessima loja. Vendem recebem e não entregam.
# None
# ainda não entregaram meu produto, apenas o outros que avia comprado junto, mas o cabo HDMI NÃO foi entregue
# Peço verificar junto a empresa e transportadora, pois até o momento meu pedido não foi entregue.
# Contando com o apoio dos senhores.
#
# None
# None
# O prazo de entrega do meu produto era dia 19/12 e até agora ele consta apenas como encaminhado para Brasilia.
# ATÉ HJ NAO RECEBI MEU PRODUTO E NAO SEI SE AINDA VAI CHEGAR,NOS EMAIL ENVIADOS NAO DESCREVE CLARAMENTE NADA
# Ainda não recebi este produto,
# Continuo aguardando
# N tenho uque opinar!
# Fiz, em Janeiro, uma compra de um Kit 3 Pendentes Tom Dixon Acabamento em Madeira Branco, com previsão de entrega para 15/02, e hoje é 19/02 e até agora não foi entregue. Quero um posicionamento!!!
# Nao recebi meu produto até agora
# None
# O produto ainda não chegou, entrei em contato com a central, mas não me souberam me responder onde meu produto estava e porque não chegou.
# Fui aos correios e fui informado que o produto estava ainda em outra cidade estou esperando pela entrega que já passou do prazo e estou precisando com urgência da ecomenda compras a e paga
# None
# Produto com prazo largo de entrega e ainda assim dois dias após o prazo previsto, não entregaram e nem há informação sobre onde este se encontra, conforme informação do rastreamento.
# None
# Nao fui informada da tentativa de entrega, meu produto retornou ao remetente e a lannister.com não tinha noção do acontecido. Busquei informações nos correios!!!
# Produto não foi entregue na data do combinado.
# Previsão para dia 09/04, hoje é 11/04 e ainda não recebi o produto.
# No site da lannister ainda constavque o produto está com a transportadora.
# None
# O produto não chegou até hoje!
# None
# None
# None
# PRODUTO ERA PRA TER CHEGADO DIA 6/6 E NÃO CHEGOU AINDA
# Barato porém duvidoso
# ATE AGORA O PRODUTO NÃO FOI ENTREGUE
# None
# Me deram dois prazos de entrega e não foi cumprido nenhum dos dois!
# O produto ainda não chegou...
# None
# None
# O prazo de entrega já acabou e o produto não chegou
# None
# ainda recebi nada ele nem manda email pra falar que vai atrasar vou ficar aguardando se não chega segunda vou ter que ligar pra vcs
# Acho que a empresa precisa ter certeza da entrega antes da venda,não sei se voltarei a usar esse site!
# Cansei de cobrar não chegou o rastreio do correio diz que não chegou na minha cidade
# Ainda não recebi meu produto e claro,já paguei por ele
# Não recebi o produto
# None
# Ouve uma demora muito grande da parte dos Correios para me entregar o produto, pois eles estavam em greve, mais enfim acabou tudo certo, recebi o produto certinho. Recomendo essa loja todos os cliente
# Não recebi pois estava em viagem, o produto ficou poucos dias no correio. Entrei em contato com as lannister mas até agora não reenviaram
# O produto ainda não foi entregue. Se eu soubesse que essa loja usava os correios nem teria comprado, pois os correios estão dificultando os esclarecimentos.
# None
# None
# Não esperava que as lannister se associasse com empresas que não cumprem com a pontualidade e o compromisso feito. Estou profundamente desapontada.
# Esta nos correios desde 8/1
# Acho que deve ser culpa dos correios
# Não sei o que houve. Era pra ser entregue o produto até o dia 5 de abril e hoje já é dia 8 e não me entregaram ainda...
# Acho que não recebi por causa da greve dos caminhoneiros.
# Custa muito
# None
# None
# None
# Faz maisde 1 mes que fiz o pedido, paguei no boleto e nao recebi o produto. Nao comprem.
# hoje 31/03/18 ainda não recebi minha mercadoria que estava prevista a entrega até o dia 28/03/18. Estou muito triste com esta situação, mas estou aguardando solução.
# None
# Falta de compromisso com o cliente. O meu produto nunca chegou apesar das minhas reclamações.
# None
# Pedido já tinha um longo prazo para entrega e ainda atrasa. Produto não recebido ainda.
# None
# None
# Não fiquei muito satisfeito pois demorou muito
# None
# None
# None
# None
# Sempre comprei na lannister, porém, não recebi meus produtos em tempo hábil.
# estou aguardando o recebimento do produto
# None
# Interponde entrega foi bem grande e mesmo assim nanotecnologia o produto.
# Estou acompanhando e ainda nem chegou no Rio.
# to esperando o produto desde a semana passada e nada de chegar
# Comprei dois produtos, o primeiro chegou certinho e o segundo, devido a greve dos caminhoneiros ainda não chegou.
# A entrega até o presente não ocorreu e já abri chamado no reclame aqui e ninguém me retorna ao meu ver uma grande falta de respeito com o cliente .
# Aguardo retorno urgente
# None
# quero meu produto
# não respondem a e-mails, houve problema na entrega e nem deram muita satisfação nem importancia
# None
# None
# Mais de mês e o produto não foi entregue.
# Tudo exatamente como eu esperava. Vou comprar mais já!
# None
# Ate o presente momento não recebi o produto,estava com o prazo de entrega dia 03/02/2018, estou no aguardo , e poderiam ser mais eficientes.
# None
# None
# achei muito bom site recomendo sim a outras pessoa
#
# Comprei dois produtos e ambos, mesmo enviados em dias diferentes, estão como em "dificuldade na entrega" segundo o rastreamento dos Correios. O que nunca me aconteceu antes.
# None
# é uma ótima opção de compra, porém as ultimas coisas que comprei ainda não chegaram, nesses pontos precisa melhorar, mas, nem todas foram assim
# Está em trânsito há 26 dias e até agora ,nada... acho muito dificil o sistema de comunicação da stark, deveria ter uma forma mais facil de realizar as reclamações!
# None
# None
# O produto não foi recebido no prazo sem nenhuma justificativa explicando o motivo do atraso
# Os preços são bons e os produtos de qualidade.O problema não é a loja, mas o serviço de entrega utilizado por eles é o pior do país. Os Correios nunca entregam no prazo.
# Ainda não recebi meu produto, o qual já foi pago, e não recebi nenhuma justificativa sobre o motivo do atraso.
# None
# não recebi o produto
# None
# Não recebi o produto dentro do prazo estipulado pela loja
# None
# ...
# None
# Estou muito insatisfeito com minha compra, produto ainda não chegou
# falta de comprometimento com o prazo
# Eu ainda não recebi meu produto tentei entrar em contato várias vezes e ainda não tive uma resposta das lojas lannister
# None
# Me arrependi pela compra pelo fato de AINDA utilizarem os Correios p/ entrega. No site falava de 6 a 11 dias, daqui uns dias já vai dar 1 mês e o Correios não entregou..... Sacanagem, pagar frete!!
# None
# produto de média qualidade
# Pedi para cancelar o envio anted de ser enviado, porém a nota ja tinha sido emitida estou aguardando a entrega parada a quase 1 mes no correio para poder retornar o pedido.
# Não recebi meu pedido e não tenho satisfação nem uma sobre o motivo, ainda estou aguardando, se não receber irei tomar providências!
# Adquiri o produto através da lannister.com em 02/03/2018, mas o até esta data não recebi o produto.
# None
# Nao posso avalia um produto que ainda nao recebi
# se fosse para avalia eu daria 0
# None
# Sempre comprei com vocês e estou tendo muito problemas que antes eu não tinha. Solicito receber meu produto o quanto antes,.
# None
# recebi antes do prazo eu recomendo
# None
# O prazo de entrega do produto já venceu e não tenho retorno do fornecedor, e não consigo mais rastrea-lo.
# Previsão de entrega da mercadoria em 11/11/2017, até agora nada e status do pedido " dificuldade na entrega, produto ainda não chegou ao destino.
#
# Se não receber até terça 14, 11 tomarei providênci
# O produto ja passou do prazo, e até agora nao chegou .
# estou aguardando minha encomenda.
# A entrega não foi feita no prazo, não deram nenhuma satisfação.
# Ainda não recebi o produto.
# Fui enganado por essa loja pois so me enviaram metade do kit que eu comprei São golpistas!!!
# None
# Chateada com a demora! Sempre compro da lannister e isso nunca tinha acontecido
# Estou muito chateada por não ter recebido meu produto. Recebi um e mail dizendo que houve um problema na entrega mas ninguem me responde qual foi o problema e se o produto ainda vai chegar.
# Tenho dúvidas se o problema é com o fornecedor ou com o entregador, pois na operacionalização da compra beleza, já quanto ao tempo de entrega (via correios) tudo atrasado.
# NÃO RECEBI O PRODUTO
# LOJA QUE NÃO ENTREGA PRODUTOS COMPRADOS A MAIS 20 DIAS E DIZ QUE PRECISA DE MAIS 20 DIAS.
# NOTA ZERO
# nao posso avaliar nada ate hj na recebi nada
# Não recebi o produto.
# targaryen não entrega no prazo, total descaso com o cliente!
# O produto não foi entrgue anda e não recebíamos nenhum contato da Empresa justificando o motivo da não entrega do produto
# Produto chegou em perfeito estado,e chegou antes do prazo,fiquei satisfeita.
# A entrega está atrasada e não tive qualquer informação pela empresa.
# None
# Era para receber o produto até 19/3 e age hoje (23/3) não recebi e não sei o motivo
# o prazo terminou e nao recebi meu produto
# Produto cancelado. Pior compra da minha vida, tanto por conta das lannister, como pela loja
# None
# O prazo já expirou e não recebi o produto
# None
# nao entregou produto no prazo
# None
# Eu pedi 6 trios de pendentes e vcs só M entregaram 6 unidades este não foi meu pedido nem meu pagamento
# None
# Loja ótima, sempre comprei e chegou antes do prazo, apenas este produto está atrasado!
# None
# Recebi o produto em perfeitas condições. Obrigada !
# *****
# Deram-me um prazo aonde não foi cumprido , pois era para dar de aniversário , mais já passou e não recebi o pedido ainda .
# Não cumpriu com o combinado
# None
# Produto não entregue , sem resposta !
# O produto não foi entregue até o momento. Realizei na mesma data a compra de outros produtos ( um outro óculos e uma bicicleta) que já foram entregues. Como proceder?
# None
# O produto está em atraso.
# gostaria de receber meu dinheiro de volta
# Péssimo.
# Gostaria de saber alguma posição da empresa porque não chegou ainda a trena.
# comprei o produto e ate hj não recebir
#
# None
# boa noite !
# até o exato momento não recebi o meu produto
# que comprei.
# gostaria de obter uma imformação sobre o motivo
# do atrazo
# None
# None
# Prazo de entrega 10/05/2018.Hoje já é 16/05/2018,o produto ainda não foi entregue.Tem uma criança de 7 anos que pergunta todos os dias pelo presente de aniversário.
# Vou comentar uma falta de profissionalismo , uma vergonha.
# None
# Demora na entrega.
# e uma loja muito boa
#
# None
# A previsão para entrega seria para até 12/12/17, e até o momento não foi entregue!
# Não recebi o produto ainda!!!
# None
# None
# A PREVISÃO PARA ENTREGA ERA DIA 12/04. HOJE SÃO 17/04 E AINDA NÃO RECEBI E NÃO CONSIGO RASTREAR O PRODUTO. A EMPRESA
# A entrega era para até dia 26/03. Até hoje ainda está no preparo para entrega.
# None
# None
# Diante da taxa alta do frente (em torno de 30% do valor do produto) e um período de entrega grande(estimado em 26 dias úteis), a empresa conseguiu não firma o prazo de entrega. Lamentável.
# Infelizmente ainda não recebi a mercadoria
# None
# None
# O produto veio diferente da imagem
# Ainda não recebi o produto.Estou insatisfeita com essa compra, pois esperava receber no tempo determinado.
# Já comprei com as lannister e o produto foi entregue no prazo, deste parceiro targaryen está atrasado.
#
# Produto com atraso. Não por causa de greve de caminhoneiros pois comprei um outro produto igual em outra loja e já recebi.
# faltou compromisso , faltou responsabilidade , não pude usar a mercadoria conforme previsto , nem mesmo uma ligação para esclarecer o motivo do atraso, estou esperando até agora.
# Falta receber um carrinho fórmula vermelho
# precisa melhorar muito
# ADUIRI TRES BONECOS POWER RANGER, UM AZUL, PRETO E VERMELHO, SÓ FALTA RECEBER O VERMELHO PRO PAPAI NOEL DE MEU NETO
# Sou cliente e essa é a primeira vez que houve problemas, até o momento não recebi a mercadoria.
# Aguardo retorno urgente!!
# atrasou a data de entrega,mas o produto é perfeito.
# Como podemos recomentar essa loja se os senhores não consegue cumprir com os prazos estabelecidos por vocês, essa foi a minha primeira compra e também será a ultima que farei.
# comprei 4 produtos na americana a quase 1 mês atrás para dar de presente de natal, e ate agora só chegou 2.peço que agilizem a entrega por favor.
# Só achei a entrega demorada. Realizei a compra dia 12 de dezembro 2017.
# None
# None
# None
# Comprei dois produtos distintos da targaryen pelo stark. Em ambos houve dificuldade na entrega e rastreamento não atualiza há semanas.
# Produto consta como entregue aos correios do RJ desde o dia 20/03 e ainda não saiu para entrega.
# Falha na última entrega
# Acho que está demorando muito
# Muito demorado
# None
# Está com um més que efetuei o pedido e o mesmo não foi entregue
# None
# Já comprei outras coisas na Americana e não tive problemas, porem até o momento não recebi esta encomenda, este é o primeiro problema que estou tendo.
# Produto ainda não foi entregue
# Estou sem trabalha por que o meu kit de tesouras fio de navalha não chego e eu quero receber sou cliente a tanto tempo e acontece isso comigo como vai ficar minha cituaçao
# Passou o prazo porém até o momento não foi realizada a entrega
# Não recebi meu produto preciso urgentemente de uma posição
# None
# Pessimo parceiro do baratheon.vcs do baratheon deveriam ter mais cuidado em suas parcerias com determinadas lojas.
# tem que ter um mínimo de atenção ao cliente
# None
# Produto como na descrição. Mas demorou muito pra chegar.
# Até agora não recebi o material, isso suja o nome do stark, que sempre entregou tudo certo.
# não tenho como recomendar, pois o produto não chegou ao centro de tratamento dos correiros em Brasilia, e, até agora, a empresa não entrou em contato para tentar esclarecer o atraso.
# Acho que pelo preço cobrado no frete, deveria haver mais respeito ao cliente em relação ao prazo!!!!
# None
# ate esta data não recebi o produto ( 07.08.18)
# Demora muito pra entregar os produtos
# Prazo de entrega enorme, produto não entregue e nenhum contato com explicação.
# Não recomendo, uma total má prestação do serviço, desrespeito Código de Defesa do Consumidor.
# Produto entregue no prazo, material muito bom, já veio montado conforme descrição do produto no período da venda.
# None
# Gostaria de uma posição, já que o prazo de entrega já expirou e meu produto não chegou.
# None
# A entrega ia ser rapida, mas parou nos correios da minha regiao, sem previsao de entrega ainda
# Sempre comprei nas lojas America as, essa é a primeira vez que aconteça essa demora na entrega.
# Preciso do óleo para fortalecer meu sistema imunológico
# Tudo muito ruim, não tem ninguém com possamos fazer reclamação pela não entrega do do produto. Não tem ouvidoria, para reclamações. Não tem nenhum pessypara informar o por que da demora da entrega.
# Preciso de uma posicao se o produto vai ser entregue ate o dia 10 ou nao .. se nao vou pedir o extorno
# None
# None
# None
# Demora em tirar nota fiscal, sem retorno da situação da compra!
# Não recebi o produto
# Ainda nas mãos do correio
# Precisod o meu produto pois efetuei o pagamento! :(
# Estou aguardando solução da minha entrega. Já paguei e ainda não recebi.
# None
# None
# None
# Rapaz eu estou precisando do meu kit de tesouras fiu de navalha e não foi entregue ainda é eu estou esperando eu quero saber se a loja vai mandar pra mim pq preciso desse kit pra mim trabalhar
# meu produto nao chegou esta atrasado.
# None
# None
# esta e minha primeira compra. espero ter maior sorte na proxima
# None
# None
# Não recebi meu produto
# None
# None
# Comprei há quase 2 meses e até o momento não recebi o produto.
# Pagar caro pelo frete e a empresa escolher os Correios como forma de transporte é certamente uma política que deve ser revista. Os Correios tem histórico negativo na entrega de e-commerce.
# None
# fico aguardando
# None
# Não recebi o meu pedido ate agora estou esperando e nada........foram mais d 20 dias e ainda atrasa....francamente....
# O produto ainda vai chegar?
# None
# Pedido não entregue (prazo de entrega não obedecido)
# Ainda não recebi meu produto
# Não recebi o produto é não consigo rastrear o site está com problema é não tenho como rastrear
# None
# None
# None
# None
# None
# None
# None
# O tapete é lindo.. não solta pêlo e é antiderrapante.
# Dor de cabeça para pegar o produto.pos a transportadora repassou para os Correios .e não tenho o protocolo dos correios para saber aond e estar.em que local eu teria de retirar
#
#
# None
# None
# - O PRAZO MÁXIMO ERA DIA 19/03/2018 E HOJE DIA 21/03/2018 ATÉ O PRESENTE MOMENTO NÃO RECEBI A MERCADORIA.
# - SE ALGUÉM ME PERGUNTAR SOBRE A COMPRA EFETUADA , FALAREI QUE NÃO RECEBI!
# None
# None
# None
# Ainda nao recebi meu produto, que seria entregue ate dia 12 de janeiro de 2018
#
# None
# óculos lindo, chegou em perfeito estado. Mas não foi entregue dentro do prazo.
# Como a entrega esta muito atrasada não vou fazer nenhuma avaliação
# None
# None
# None
# O PRODUTO CONSTA COMO ENTREGUE NO DIA 16-08, MAS HOJE DIA 20-08, O PRODUTO AINDA NÃO FOI ENTREGUE.
# None
# Ainda nao recebi meu produto, nao conseguem me informar onde está e ja demorou demais p chegar
# Entrega atrasada sera que é correios em greve?
# O produto chegou bem lacrado e em perfeito estado, mas houve demora na entrega.. Passou do prazo previsto.
# Não recebi o produto
# None
# Os produtos chegaram intactos, bem embalados,foram os que eu pedi.
# Estou dando três estrelas pelo prazo que não foi cumprido!!!!
# None
# None
# None
# None
# Minha encomenda ainda não chegou, peço que resolvam este problema, pois preciso do meu equipamento, e se possível enviar outro produto ou fazer a devolução do meu dinheiro,mas preciso do produto!
# Ainda não recebi o produto adquirido e não houve nenhuma comunicação sobre o atraso.
# None
# None
# Previsão estava para 20/12/2017 e ainda não chegou.
# Não recebi o produto até hoje, espero que seja resolvido o meu problema.
# Muito bom e eficiente eu recomendo
# O produto ainda não foi entregue e o prazo, que era muito longo, já foi ultrapassado.
# Tudo maravilhoso recomendo!
# A previsão seria para o dia 5, mas temos que dar um desconto por causa dos correios.
# Estou muito chateado, por não ter recebido, o produto que eu comprei.
# não recebi o produto até o momento
# Ainda não recebi
# Produto comprado em 08/03/2018 e promessa de entrega até 29/03/2018, entretanto,até o momento não recebi o objeto comprado e nenhuma satisfação me foi dada pelo vendedor.
# None
# Eu não recebi o produto.
# Lindos amei
# Até o momento não foi entregue
# None
# Ola tem como wu rastrear ou verificar quem recebeu?
# None
# None
# Esperava qualidade no atendimento e estou tendo muita dor de cabeça.
# O produto não foi entregue.
# Mensagem da transportadora diz que "Objeto ainda não chegou à unidade"
# Um dia antes de vencer o prazo de entrega recebi e-mail que a entrega não tinha sido efetuada por não encontrar ninguém em casa. Informação não procede. Agora manda retirar nos correios.
# demora com a entrega
# None
# None
# None
# AINDA NÃO RECEBI O PRODUTO COMPRADO.
# Estou aguardando o produto
# Estou aguardando a encomenda.
# Recebi o aviso de dificuldade na entrega, mas ninguém entrou em contato para dizer o q realmente aconteceu.
# Ainda não recebi o produto por conta dos correios que "perderam" minha encomenda...
# ATÉ A DATA DE HOJE NAO RECEBI O PRODUTO! QUE ERA P TER CHEGADO A MAIS DE 10 DIAS! COMPLETO DESCASO E FALTA DE PROFISSIONALISMO E RESPEITO COM O CONSUMIDOR!
# Não sei como a lannister resolve usar o próprio nome pra vender produtos de um loja tão descompromissada com o cliente. Não respondem o meu e-mail reclamando do atraso e da falta de atenção .
# Não recomendaria a targaryen a outros compradores.
# Ainda não recebi o prduto
# None
# Devido a greve dos correios, o produto ficou parado e não chegou no prazo previsto
# Prazo da entrega já venceu, e até agora n chegou minha mercadoria, 2 meses já.
# None
# None
# None
# Meu produto não chegou ainda, há passou do prazo e não recebi.
# None
# Paguei pelo frete, deveria receber o produto em minha casa , não vou busvar nos correios, eu trabalho
# None
# None
# None
# a loja da um prazo , e o produto nao é entregue nele.
# E mesmo com o atraso não fornecem nenhum tipo de informação sobre o atraso
# ameii. veio bem certinho, melhor do que esperávamos, unica coisa que a caixa veio destruída, e tive que retirar no correio, só precisa melhorar a qualidade da embalagem
# Esperando a entrega
# Falta de respeito com cliente
# None
# None
# None
# Até o momento não tive nenhum retorno de uma satisfação pelo atraso na entrega.
# Não recebi o produto e tão pouco orientação de onde retirá-lo
# Comprei o telefone mas veio com uma cor diferente comprei um azul e preto
# None
# Ainda não recebi o produto e gostaria de ter uma posição, isso é uma falta de respeito com o consumidor, não dão nenhuma satisfação já entrei em contato 3 vezes e até agora nada l.
# Até o momento o produto não chegou, o prazo de entrega já excedeu.
# Quero posição!
# Não recebi o produto e nem satisfação.
# Pelo amor de Deus, preciso de um nr de telefone para falar com um HUMANO no stark, a URA não resolve nada.
# Lindo edredom
# Estou no aguardo
# Um dos produtos chegou com atraso, mas fora isso sempre que peço chega tudo direitinho.
# Tô muito chateada por conta da demora .
# None
# None
# None
# None
# Ainda não recebi o produto
# None
# JÁ foi comprado enviado nas não chegou recomprado e nada previso do cod de rastreio pois com os vorreiis somente com cod vcs deverian estar acompanhando este caso mas preferem vender e não dão aten
# nao recebi meu produto ate agora
# None
# None
# None
# Ainda não recebi o produto como vou avaliar, ainda estou aguardando a entrega do produto
# o produto que pedi não condiz com a foto, pior é enviar ao cliente uma borracha de vedaçao que vc entra com o valor de 3,00. É uma tiraçao
# Até o momento não recebi o produto pago
# None
# None
# None
# None
# o produto não gostei pq não resolveu o meu problema.
# Faz um mês que comprei o livro, já paguei e até agora não vi o produto. Assim não da, lannister!
# Minha opinião é que se comprei o produto ele tinha que ser entregue e não receber um notificação que seria dado como entregue o produto...então a empresa me devolva meu dinheiro!!
# Ainda nao recevi o produto.
# Gostaria de saber porque meu produto ainda não chegou na minha residência.e ninguém me deu uma satisfação ou algo do tipo.
# muito bom! recomendo!
# None
# None

# %% [markdown]
# **Para melhorar a visualização, podemos utilizar uma nuvem de palavras**
# - https://pypi.org/project/wordcloud/

# %%
# Instalando o wordcloud 
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\cross\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\cross\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\cross\anaconda3\lib\site-packages (from wordcloud) (10.0.1)
# Requirement already satisfied: matplotlib in c:\users\cross\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cross\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\cross\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# Usando a nuvem de palavras
from wordcloud import WordCloud

# %% [markdown]
# **Para usar a biblioteca, precisamos ter um texto, então podemos transformar todos os comentários em um único texto**

# %%
# Transformando todos os comentários em um único texto
texto = ''
for i in avaliacoes.loc[avaliacoes.order_id.isin(ids),'review_comment_message']:
    if i:
        texto += i 
        texto += ' '

# %%
texto
# Out:
# 'Sempre compro pela Internet e a entrega ocorre antes do prazo combinado, que acredito ser o prazo máximo. No stark o prazo máximo já se esgotou e ainda não recebi o produto. Nada de chegar o meu pedido. Comprei o produto dia 25 de fevereiro e hoje dia 29 de marco não fora entregue na minha residência. Não sei se os correios desse Brasil e péssimo ou foi a própria loja que demorou postar. Não posso! Estou aguardando a chegada do produto que comprei!Logo que isso aconteça, terei minha opinião formada! Comprei dois produtos e recebi somente um. Mandei dois emails para a loja e não tive nenhum retorno. Estou insatisfeita. Até agora nao recebi.Comprei este aparelho por questao de saude,portanto nao recomendo esta loja. comprei um produto para ser entregue por essa loja\r\ne ainda não recebi\r\npois assim já se passou a data de entrega Até agora não recebi nada, a colcha estava prevista para anteontem(18/12) e até agora nada Até o momento eu n recebir o produto Não recebi o produto.e agora? Preciso de uma previsão. Recebi outra boneca, quero devolver e não consigo contato! Jamais compraria novamente dessa loja!  Estou esperando há mais de vinte dias e ainda não recebi meu produto e não consigo nenhuma informação.  Gostei muito do que comprei com vcs muito obrigada breve farei outras compras vanda Produto não foi entregue! Muito ruim, não veio um produto e o outro veio errado..  Otimo material bem resistente espaçosa 👏👏👏 gostei! Sem pontualidade não da satisfação ao cliente. Não posso dar opinião sobre produto pois não recebi, sobre a loja eu não recomendo, pois atrasa as entregas. NÃO RECEBI O PRODUTO, O PRODUTO CONSTA COMO ENVIADO PARA O CORREIO DE RIBEIRÃO PRETO. O CORREIO NÃO RECEBEU O PRODUTO. ENVIE VARIAS MENSAGEM PARA A targaryen E NÃO OBTIVE. ESTA targaryen ESTA SUJANDO SEU NOME Vcs tá deixando a desejar comprei produtos com vcs e vcs demora entregar e ainda cancela o pedido sem autorização  atendeu as expectivas Já entrei em contato com a lannister pelo telefone e eles me falam q vai mandar o link direto com o parceiro pra eu saber detalhes da entrega da conta e esse link n veio. Péssimo suporte ao cliente ótima Ainda não recebi o produto... varios dias que fiz a compra. entrega demorada pelas compras que faço online, ainda estou aguardando a entrega quero o meu produto To esperando até agora nunca recebi nenhum relógio eu comprei não recomendado essa loja no site dizia que chegaria até 13/03 e ainda não chegou! Não recebi até agora a mercadoria.  A empresa prestou ótima assistência, o produto chegou em ótimo estado.  Minha avaliação ta sendo esta pq aqui aparece q recebi o produto e ainda não chegou em casa.Por favor, queria saber o q está acontecendo ???\r\nAtenciosamente, \r\nJuliana o produto nao poder ser avaliado ainda nao recebi Simplesmente não recebi o produto Eu comprei um celular smartphone , não chegou não recomendo comprar nesta loja targaryen e lannister porque não chegou meu produto. Eu comprei está data,07/06/2017. Era pra chegar no dia .05/07/2017. produto em atraso. Estou aguardando espero que chegue logo PRODUTO NÃO ENTREGUE COM MUITO ATRASO E SEM PREVISÃO!!!!!\r\nPRECISO DE UM RETORNO COM URGENCIA. Foi a segunda vez que tentei comprar com essa loja e o pedido não foi entregue no prazo. amei  Ainda não recebi o produto. Apesar da greve dos caminhoneiros, os demais produtos referentes a este pedido (e a outros) já foram entregues. Será preciso que a loja verifique junto à transportadora... Comprei e paguei o produto ha mais de 20 dias e ainda não recebi o mesmo. Fiz a compra e meu pedido não chegou e dar como entregue!!! Ao efetuar rastreio consta em trânsito a 19 dias  Excelente produto  ruin Quero meu dinheiro de volta  Tive que retirar no correio, se tivesse sido informada que não me entregaria em casa não teria feito o pedido... O produto ainda não foi entregue. Já realizei compras mais recentes na lannister, porem i produto deste pedido ainda não foi entregue. Produto ainda não foi entregue, mas deixo ...

# %%
# Gerando a nuvem de palavras
wordcloud = WordCloud(stopwords=['o','e','dia','que']).generate(texto)

# %%
# Exibindo a imagem
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Entendendo melhor o WordCloud
# ?WordCloud

# %%
# E se a gente tentar agrupar por frases?
texto = ''
for i in avaliacoes.loc[avaliacoes.order_id.isin(ids),'review_comment_message']:
    if i:
        i = i.replace(' ','')
        texto += i 
        texto += ' '

# %%
# Gerando a nuvem de palavras
wordcloud = WordCloud().generate(texto)

# %%
# Exibindo a imagem
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
